# %% [markdown]
# **Author:** Elias Rafael Ruiz-Morales
#
# **Institution:** Wellcome Sanger institute
#
# **July, 2023**

# %% [markdown]
# ---

# %% [markdown]
# # Listeria: Merging genes tables from Differential expression

# %%
import numpy as np
import pandas as pd
import os
import sys
import scipy
import matplotlib.pyplot as plt

import seaborn as sns
import scanpy as sc

# %% [markdown]
# ### Note
# To run this chunk you need:
#
# *rpy2==3.4.2  ///  anndata2ri==1.0.6*

# %%
import rpy2.robjects as ro
import rpy2.robjects.numpy2ri

import rpy2.rinterface_lib.callbacks
import logging
# Itoliste R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)
import anndata2ri
anndata2ri.activate()
# %load_ext rpy2.ipython

# %% [markdown]
# ## Load subset Listeria 24H post-infection

# %%
adata= sc.read('../../../data_integration/results/scVI/listeria_singleCell_24h.h5ad')

# %% [markdown]
# #### Subset immune cells

# %%
adata =adata[[ i in ['F','PV','F_p','F_sm','Endo_f'] for i in adata.obs.cell_type ]]
adata.write ('../data/listeria_singleCell_24h_FibroEndo.h5ad')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
del(adata)

# %% [markdown]
# # Filtering DEGs

# %% [markdown]
# ## Reading the DEGs tables per cell type

# %%
df1 = pd.read_csv('../results/SC_limma_fibroEndo_LIS_24h/1_DEGs_SC_LIS_24h_F.tsv', index_col=0,sep='\t')
df2 = pd.read_csv('../results/SC_limma_fibroEndo_LIS_24h/2_DEGs_SC_LIS_24h_PV.tsv', index_col=0,sep='\t')
df3 = pd.read_csv('../results/SC_limma_fibroEndo_LIS_24h/3_DEGs_SC_LIS_24h_Endof.tsv', index_col=0,sep='\t')

# %%
df1.head()
# Out:
#              logFC    logCPM           F        PValue  bonferroni  p_val_adj
# SLC30A4   0.773521  5.872970  121.331122  5.458952e-10    0.000004   0.000001
# PRLR     -1.230642  5.851608  125.116078  4.174005e-10    0.000003   0.000001
# TMEM176B -1.342739  4.737912  136.121616  1.987307e-10    0.000002   0.000001
# TMEM176A -1.385467  5.007965  106.805219  1.643066e-09    0.000012   0.000002
# IMPA2    -1.103366  4.534453  104.991727  1.902154e-09    0.000014   0.000002

# %%
df2.head()
# Out:
#                logFC    logCPM          F        PValue  bonferroni  p_val_adj
# IL1B        1.441441  5.748745  83.425492  2.861042e-09    0.000021   0.000021
# AL133453.1  0.628851  6.338373  70.006608  1.441496e-08    0.000108   0.000036
# LINC02326   0.805504  6.203114  71.988762  1.119157e-08    0.000084   0.000036
# STC1        1.174349  9.604055  65.198570  2.726236e-08    0.000205   0.000041
# AC009554.1  0.919839  5.432419  66.342901  2.335296e-08    0.000175   0.000041

# %%
df3.head()
# Out:
#              logFC    logCPM           F        PValue    bonferroni  \
# CLEC14A  -0.863948  5.789381  118.641267  3.483002e-11  2.581950e-07
# C15orf48  0.954024  4.448099  126.433440  1.752048e-11  1.298793e-07
# IL1B      1.031443  5.523735   98.954441  2.370360e-10  1.757148e-06
# C1orf56   0.969427  5.265645  101.557146  1.808770e-10  1.340841e-06
# DTWD2     1.169978  4.599164   95.351859  3.479421e-10  2.579295e-06
#
#              p_val_adj
# CLEC14A   1.290975e-07
# C15orf48  1.290975e-07
# IL1B      4.392869e-07
# C1orf56   4.392869e-07
# DTWD2     5.158590e-07

# %% [markdown]
# #  F

# %% [markdown]
# ### Defining a thershold for significant Up reg in HBC

# %%
df1up= df1[(df1['logFC'] > 0) ]
df1_down= df1[(df1['logFC'] < 0) ]

# %%
#df1_down['avg_log2FC']= df1_down['avg_log2FC']*-1

# %%
df1_temp = pd.concat([df1up, df1_down])

# %%
df1_temp.loc[['IL1B']]
# Out:
#         logFC   logCPM          F    PValue  bonferroni  p_val_adj
# IL1B  1.24458  7.55623  30.938537  0.000019    0.139812   0.000298

# %%
# %%R
#
# library(Cairo)
# library(ggplot2)
# library(ggrepel)
# library(EnhancedVolcano)
# library(magrittr)

# %%
# %%R -i df1_temp
#
# EnhancedVolcano(df1_temp, lab = rownames(df1_temp), x="logFC", y="p_val_adj",
#                 #selectLab = c('CXCL8','IL1B'),
#
#                 pCutoff=0.05,
#                 FCcutoff = 0.1, title = "Lm_F", subtitle = bquote(italic(single_cell)),
#                 ylab = bquote(-Log[10] * "(p-val_adj)"), xlim = c(-2, 2), pointSize =1,
#                 labSize = 4)
# #ggsave("volcano_plot_Pf_VCT_fusing_SN_day2.eps",  device=cairo_ps, width =7,   height =7)

# %%
x= df1_temp[(df1_temp['p_val_adj'] < 0.05) ]

# %%
plt.hist(x['logFC'], bins = 100)
plt.axvline(0.1, linestyle = '--', color = 'red')
plt.axvline(-0.1, linestyle = '--', color = 'red')

# %% [markdown]
# ## Note:
# Save DEGs list:
#
#     p_val_adj < 0.05
#
#     avg_log2FC > 0.1
#
#     ==> Input to metascape

# %% [markdown]
# ### Significant Up reg in F

# %%
upDEG= df1[(df1['p_val_adj'] < 0.05) & (df1['logFC'] > 0.1)]

# %%
upDEG.to_csv('../results/SC_limma_fibroEndo_LIS_24h/1_DEGs_UP_SC_LIS_24h_F.tsv', index=True, sep='\t')

# %%
upDEG.head()
# Out:
#               logFC    logCPM           F        PValue  bonferroni  p_val_adj
# SLC30A4    0.773521  5.872970  121.331122  5.458952e-10    0.000004   0.000001
# ATP10B     1.159572  4.096377  112.813973  1.026411e-09    0.000008   0.000002
# WDR45B     0.466109  6.572808   99.179367  3.086850e-09    0.000023   0.000002
# MARCKS     0.681913  9.354571   99.287132  3.058607e-09    0.000023   0.000002
# LINC02326  0.698494  6.232710   96.452308  3.906280e-09    0.000030   0.000002

# %%
upDEG.shape
# Out:
# (1264, 6)

# %%
list(upDEG.index)
# Out:
# ['SLC30A4',
#  'ATP10B',
#  'WDR45B',
#  'MARCKS',
#  'LINC02326',
#  'NGLY1',
#  'AL133453.1',
#  'IL32',
#  'TNFAIP3',
#  'CCL5',
#  'INSIG1',
#  'CA12',
#  'LINC01128',
#  'NAP1L1',
#  'AC020611.2',
#  'BCAT1',
#  'SLC41A2',
#  'AC092040.1',
#  'SQLE',
#  'ALDH1A3',
#  'AC015802.6',
#  'AMPD3',
#  'DDX21',
#  'ENO2',
#  'ICAM1',
#  'RGS16',
#  'SLC6A8',
#  'TIMP3',
#  'IL1RAP',
#  'SLC25A37',
#  'AC079921.1',
#  'CYB5R2',
#  'ADM',
#  'BTG3',
#  'TUBB2B',
#  'ETS1',
#  'DLEU2',
#  'SEMA5A',
#  'SPTY2D1',
#  'SEC24A',
#  'HK2',
#  'HAS1',
#  'MAP2K1',
#  'ACSL4',
#  'UGP2',
#  'CCL3',
#  'CPNE4',
#  'USP3-AS1',
#  'KDM7A',
#  'SDK1',
#  'NINJ1',
#  'NUP58',
#  'CD40',
#  'RAB8B',
#  'GAS5',
#  'SOD2',
#  'ZFAS1',
#  'HPSE2',
#  'C12orf73',
#  'SPAG9',
#  'TEX26-AS1',
#  'MT-ND3',
#  'ZEB1',
#  'TOP1',
#  'S100A8',
#  'MT1A',
#  'SRP54',
#  'NDUFAF2',
#  'CD44',
#  'GRIK1',
#  'AL135878.1',
#  'C15orf48',
#  'AC104461.1',
#  'CSTB',
#  'HILPDA',
#  'RAI14',
#  'CYTOR',
# ...

# %%
#list(upDEG.index)

# %% [markdown]
# ### Significant Down reg in F

# %%
downDEG= df1[(df1['p_val_adj'] < 0.05) & (df1['logFC'] < -0.1)]

# %%
downDEG.to_csv('../results/SC_limma_fibroEndo_LIS_24h/1_DEGs_DOWN_SC_LIS_24h_F.tsv', index=True, sep='\t')

# %%
downDEG.head()
# Out:
#              logFC    logCPM           F        PValue  bonferroni  p_val_adj
# PRLR     -1.230642  5.851608  125.116078  4.174005e-10    0.000003   0.000001
# TMEM176B -1.342739  4.737912  136.121616  1.987307e-10    0.000002   0.000001
# TMEM176A -1.385467  5.007965  106.805219  1.643066e-09    0.000012   0.000002
# IMPA2    -1.103366  4.534453  104.991727  1.902154e-09    0.000014   0.000002
# HSPB6    -1.347979  5.589492  103.939215  2.072911e-09    0.000016   0.000002

# %%
downDEG.shape
# Out:
# (1293, 6)

# %%
list(downDEG.index)
# Out:
# ['PRLR',
#  'TMEM176B',
#  'TMEM176A',
#  'IMPA2',
#  'HSPB6',
#  'WFDC1',
#  'PROS1',
#  'ASB4',
#  'PTGDS',
#  'NDRG2',
#  'DLK1',
#  'PROK1',
#  'PTH1R',
#  'PRXL2A',
#  'KIAA0040',
#  'PCOLCE',
#  'SELENBP1',
#  'PEBP1',
#  'ANTXR1',
#  'TCF21',
#  'BSG',
#  'LGALS3BP',
#  'VAMP5',
#  'FCGRT',
#  'FBLN1',
#  'PITX2',
#  'ITGA4',
#  'PLTP',
#  'SPON1',
#  'LRPAP1',
#  'MMP2',
#  'CYSLTR2',
#  'HTRA3',
#  'PLEKHG1',
#  'CDC25B',
#  'AC024230.1',
#  'DISP1',
#  'SERPINF1',
#  'GSN',
#  'GPR153',
#  'MXRA8',
#  'APOD',
#  'DES',
#  'CST3',
#  'MFAP2',
#  'LINC02268',
#  'HSD17B2',
#  'LUM',
#  'SERPINE2',
#  'WWOX',
#  'FXYD1',
#  'AC002451.1',
#  'GLI3',
#  'CYTL1',
#  'LINC00535',
#  'PLP2',
#  'DCN',
#  'CD99',
#  'PITX1',
#  'KANK2',
#  'APMAP',
#  'PPP1R16A',
#  'DUSP9',
#  'PODN',
#  'AQP3',
#  'LINC02438',
#  'ECM1',
#  'EYA2',
#  'PCOLCE2',
#  'PPBP',
#  'GLIPR2',
#  'LSP1',
#  'ST3GAL5',
#  'BIN1',
#  'CTSD',
#  'AKR1B1',
#  'PALM',
#  'CFD',
#  'COL4A5',
#  'GRN',
# ...

# %% [markdown]
# #  PV

# %% [markdown]
# ### Significant Up reg in PV

# %%
upDEG= df2[(df2['p_val_adj'] < 0.05) & (df2['logFC'] > 0.1)]

# %%
upDEG.to_csv('../results/SC_limma_fibroEndo_LIS_24h/2_DEGs_UP_SC_LIS_24h_PV.tsv', index=True, sep='\t')

# %%
upDEG.head()
# Out:
#                logFC    logCPM          F        PValue  bonferroni  p_val_adj
# IL1B        1.441441  5.748745  83.425492  2.861042e-09    0.000021   0.000021
# AL133453.1  0.628851  6.338373  70.006608  1.441496e-08    0.000108   0.000036
# LINC02326   0.805504  6.203114  71.988762  1.119157e-08    0.000084   0.000036
# STC1        1.174349  9.604055  65.198570  2.726236e-08    0.000205   0.000041
# AC009554.1  0.919839  5.432419  66.342901  2.335296e-08    0.000175   0.000041

# %%
upDEG.shape
# Out:
# (486, 6)

# %%
list(upDEG.index)
# Out:
# ['IL1B',
#  'AL133453.1',
#  'LINC02326',
#  'STC1',
#  'AC009554.1',
#  'CDC42SE1',
#  'AC020611.2',
#  'WDR45B',
#  'CCL4',
#  'CCL3',
#  'C12orf40',
#  'C15orf48',
#  'SPP1',
#  'AMPD3',
#  'BCAT1',
#  'RABGEF1',
#  'ABI3BP',
#  'CREB5',
#  'MIF',
#  'MYO10',
#  'BIRC2',
#  'OTUD4',
#  'SDC4',
#  'AC018682.1',
#  'CSTB',
#  'AC026202.2',
#  'CD44',
#  'ICAM1',
#  'SNRNP27',
#  'IQCG',
#  'SLC2A1',
#  'MT2A',
#  'SUPT3H',
#  'MARCKS',
#  'SLC41A2',
#  'RNMT',
#  'AC024588.1',
#  'C1orf56',
#  'BTG3',
#  'DTWD2',
#  'BZW1',
#  'LOX',
#  'SEC61G',
#  'GFPT2',
#  'AC091180.5',
#  'POU2F2',
#  'LIF',
#  'FSTL1',
#  'CLEC2B',
#  'NFKBIA',
#  'CTNNB1',
#  'GRIK1',
#  'SDCBP2-AS1',
#  'B4GALT1',
#  'AC107021.1',
#  'SPECC1L',
#  'ELK3',
#  'CXCL8',
#  'INHBA',
#  'AC093110.1',
#  'UFM1',
#  'S100A8',
#  'NUP58',
#  'EIF5B',
#  'ZDHHC9',
#  'SRGN',
#  'SPAG9',
#  'HK2',
#  'CCL20',
#  'EPB41L3',
#  'HILPDA',
#  'LINC02327',
#  'ADAMTS4',
#  'P4HA1',
#  'TNFAIP3',
#  'ZFAS1',
#  'RIPK2',
# ...

# %%
#list(upDEG.index)

# %% [markdown]
# ### Significant Down reg in PV

# %%
downDEG= df2[ (df2['p_val_adj'] < 0.05) & (df2['logFC'] < -0.1)]

# %%
downDEG.to_csv('../results/SC_limma_fibroEndo_LIS_24h/2_DEGs_DOWN_SC_LIS_24h_PV.tsv', index=True, sep='\t')

# %%
downDEG.head()
# Out:
#            logFC     logCPM          F        PValue  bonferroni  p_val_adj
# DLK1   -0.480718  10.740276  58.101704  7.467345e-08    0.000561   0.000080
# TKT    -0.539574   7.466866  52.673656  1.717090e-07    0.001290   0.000092
# FCGRT  -0.530525   6.470850  49.132527  3.055859e-07    0.002295   0.000143
# COL4A1 -0.502784  11.549893  46.753890  4.574869e-07    0.003436   0.000191
# ITM2C  -0.517511   6.378353  45.570930  5.620844e-07    0.004221   0.000211

# %%
downDEG.shape
# Out:
# (376, 6)

# %%
list(downDEG.index)
# Out:
# ['DLK1',
#  'TKT',
#  'FCGRT',
#  'COL4A1',
#  'ITM2C',
#  'CAVIN3',
#  'PITX2',
#  'PPP1R14A',
#  'SLC9A3R2',
#  'ST8SIA4',
#  'ISYNA1',
#  'CALD1',
#  'AC024230.1',
#  'SPARC',
#  'PEBP1',
#  'ADH5',
#  'CD248',
#  'PCOLCE',
#  'COL4A2',
#  'KCNK3',
#  'LAMC3',
#  'PLA2G2A',
#  'ADAMTSL3',
#  'SOX6',
#  'AOPEP',
#  'OAZ2',
#  'GAS6',
#  'GSN',
#  'PRKAR2B',
#  'FBLIM1',
#  'BSG',
#  'NDUFV1',
#  'GPC3',
#  'IGFBP7',
#  'ENPP2',
#  'TBX2',
#  'PTH1R',
#  'S100A4',
#  'PPIC',
#  'QPRT',
#  'ECH1',
#  'EDNRB',
#  'HMGN3',
#  'LINGO1',
#  'MXRA8',
#  'ADA',
#  'CRYAB',
#  'MRTFB',
#  'CCDC3',
#  'GATA4',
#  'RABL6',
#  'H19',
#  'HTRA3',
#  'PRDM6',
#  'AC009271.1',
#  'MEST',
#  'CARMIL1',
#  'NDRG2',
#  'APOE',
#  'GATM',
#  'SPATA22',
#  'VWA1',
#  'PLCB1',
#  'FLOT1',
#  'LUM',
#  'KIAA0040',
#  'RHOBTB1',
#  'ITGA4',
#  'LAMB1',
#  'MCAM',
#  'BMP5',
#  'IFT122',
#  'CCDC68',
#  'TUBG2',
#  'NQO1',
#  'EBPL',
#  'GRN',
#  'GSDMD',
#  'VCAN',
#  'COL3A1',
#  'B4GAT1',
#  'TALDO1',
# ...

# %% [markdown]
# #  Endo_f

# %% [markdown]
# ### Significant Up reg in Endof

# %%
upDEG= df3[ (df3['p_val_adj'] < 0.05) & (df3['logFC'] > 0.1)]

# %%
upDEG.to_csv('../results/SC_limma_fibroEndo_LIS_24h/3_DEGs_UP_SC_LIS_24h_Endof.tsv', index=True, sep='\t')

# %%
upDEG.head()
# Out:
#              logFC    logCPM           F        PValue    bonferroni  \
# C15orf48  0.954024  4.448099  126.433440  1.752048e-11  1.298793e-07
# IL1B      1.031443  5.523735   98.954441  2.370360e-10  1.757148e-06
# C1orf56   0.969427  5.265645  101.557146  1.808770e-10  1.340841e-06
# DTWD2     1.169978  4.599164   95.351859  3.479421e-10  2.579295e-06
# CXCL5     0.943957  5.881886   89.663507  6.534115e-10  4.843740e-06
#
#              p_val_adj
# C15orf48  1.290975e-07
# IL1B      4.392869e-07
# C1orf56   4.392869e-07
# DTWD2     5.158590e-07
# CXCL5     8.072899e-07

# %%
upDEG.shape
# Out:
# (349, 6)

# %%
list(upDEG.index)
# Out:
# ['C15orf48',
#  'IL1B',
#  'C1orf56',
#  'DTWD2',
#  'CXCL5',
#  'CXCL1',
#  'PRG2',
#  'CDYL2',
#  'P4HA1',
#  'AC092069.1',
#  'CXCL3',
#  'S100A8',
#  'AC091180.5',
#  'CA8',
#  'ARHGEF28',
#  'CCL3',
#  'AC090015.1',
#  'CXCL8',
#  'AC107021.1',
#  'AL133453.1',
#  'AC068282.1',
#  'CCL20',
#  'ZFHX3',
#  'FOSL2',
#  'IL32',
#  'FSTL1',
#  'COL25A1',
#  'SDCBP2-AS1',
#  'ARL14EPL',
#  'AC092142.1',
#  'UNC5D',
#  'TIMP1',
#  'SPP1',
#  'LINC02669',
#  'A2ML1-AS1',
#  'COCH',
#  'AC023424.3',
#  'BMPR2',
#  'ABCF1',
#  'LGALS1',
#  'LOXL2',
#  'SYNC',
#  'IRF2BPL',
#  'COL15A1',
#  'JAZF1',
#  'LINC01446',
#  'AC083870.1',
#  'LINC00513',
#  'AC017101.1',
#  'ZBTB20-AS5',
#  'AP001442.1',
#  'LINC02603',
#  'MCPH1',
#  'NMT1',
#  'NAP1L1',
#  'AL606489.1',
#  'PDGFB',
#  'CANX',
#  'LINC00221',
#  'STC1',
#  'MYO1B',
#  'MT2A',
#  'CXCL2',
#  'NCL',
#  'HSPG2',
#  'CTSS',
#  'CFDP1',
#  'PRDM1',
#  'AP002954.1',
#  'ADAMTS9',
#  'IGFBP2',
#  'RBMS3-AS3',
#  'SNRNP27',
# ...

# %%
#list(upDEG.index)

# %% [markdown]
# ### Significant Down reg in Endof

# %%
downDEG= df3[ (df3['p_val_adj'] < 0.05) & (df3['logFC'] < -0.1)]

# %%
downDEG.to_csv('../results/SC_limma_fibroEndo_LIS_24h/3_DEGs_DOWN_SC_LIS_24h_Endof.tsv', index=True, sep='\t')

# %%
downDEG.head()
# Out:
#             logFC     logCPM           F        PValue    bonferroni  \
# CLEC14A -0.863948   5.789381  118.641267  3.483002e-11  2.581950e-07
# KLF2    -0.554911   8.170317   63.922279  1.791986e-08  1.328399e-04
# DEPP1   -0.567558   7.957905   55.592849  6.462103e-08  4.790357e-04
# H19     -0.285683  11.988171   50.734393  1.454829e-07  1.078465e-03
# WIPI1   -0.412478   6.048414   47.835347  2.422060e-07  1.795473e-03
#
#             p_val_adj
# CLEC14A  1.290975e-07
# KLF2     9.488567e-06
# DEPP1    2.521241e-05
# H19      3.994315e-05
# WIPI1    5.791848e-05

# %%
downDEG.shape
# Out:
# (203, 6)

# %%
list(downDEG.index)
# Out:
# ['CLEC14A',
#  'KLF2',
#  'DEPP1',
#  'H19',
#  'WIPI1',
#  'FCGRT',
#  'STXBP6',
#  'MACROD2',
#  'UBE2J2',
#  'TUBA1A',
#  'DLK1',
#  'VAMP5',
#  'MTUS1',
#  'KHDRBS2',
#  'PRDX6',
#  'KCNMB4',
#  'TCP11L2',
#  'MPG',
#  'ARHGEF3',
#  'BCAM',
#  'GIMAP1',
#  'OSBPL10',
#  'FAM89A',
#  'VAV3',
#  'AL117329.1',
#  'PIH1D1',
#  'BCAS3',
#  'TMEM44',
#  'ICAM2',
#  'IGFBP4',
#  'SOX18',
#  'TALDO1',
#  'ERP29',
#  'CTNNBIP1',
#  'TKT',
#  'FDFT1',
#  'MVB12A',
#  'PEBP1',
#  'LRP6',
#  'MEG3',
#  'EMILIN2',
#  'JUNB',
#  'TNFRSF6B',
#  'KANK3',
#  'TJP1',
#  'NR2F6',
#  'CASC9',
#  'DHFR',
#  'NHLRC3',
#  'ICA1',
#  'CD320',
#  'ITGB5',
#  'MZT2B',
#  'MRPS9',
#  'PPP1R35',
#  'MEG8',
#  'FAR2',
#  'HIBCH',
#  'YBX3',
#  'ACO2',
#  'PLAGL1',
#  'STEAP1B',
#  'AC104041.1',
#  'MYLIP',
#  'PYCR2',
#  'ACTR10',
#  'MT-CO1',
#  'MMRN1',
#  'VEGFC',
#  'SLC25A5',
#  'GFOD1',
#  'MARCKSL1',
#  'CARHSP1',
#  'MRRF',
#  'STRN',
#  'PLTP',
#  'TMEM243',
#  'AC013287.1',
#  'TUBB4B',
# ...
