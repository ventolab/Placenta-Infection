# %% [markdown]
# **Author:** Elias Rafael Ruiz-Morales
#
# **Institution:** Wellcome Sanger institute
#
# **July, 2023**

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import os
import sys
import scipy
import matplotlib.pyplot as plt

import seaborn as sns
import scanpy as sc

# %% [markdown]
# ### Note
# To run this chunk you need:
#
# *rpy2==3.4.2  ///  anndata2ri==1.0.6*

# %%
import rpy2.robjects as ro
import rpy2.robjects.numpy2ri

import rpy2.rinterface_lib.callbacks
import logging
# Itoliste R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)
import anndata2ri
anndata2ri.activate()
# %load_ext rpy2.ipython

# %% [markdown]
# ## Load subset Malaria 24H post-infection

# %%
adata= sc.read('../../../data_integration/results/scVI/malaria_singleCell_24h.h5ad')

# %% [markdown]
# #### Subset immune cells

# %%
adata =adata[[ i in ['HBC','HBC_p','PAMM1'] for i in adata.obs.cell_type ]]
adata.write ('../data/malaria_singleCell_24h_Immune.h5ad')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
del(adata)

# %% [markdown]
# # Filtering DEGs

# %%
df1 = pd.read_csv('../results/SC_limma_Immune_MAL_24h/1_DEGs_SC_MAL_24h_HBC.tsv', index_col=0,sep='\t')
df2 = pd.read_csv('../results/SC_limma_Immune_MAL_24h/2_DEGs_SC_MAL_24h_PAMM1.tsv', index_col=0,sep='\t')

# %%
df1.head()
# Out:
#                logFC    logCPM           F        PValue    bonferroni  \
# ZNF341-AS1  0.940907  3.927395  199.622904  2.783162e-13  2.283585e-09
# NFIA       -1.279954  4.309887  187.746713  5.441978e-13  4.465143e-09
# Z82244.2    2.443107  3.379129  178.314946  9.526965e-13  7.816875e-09
# PTGIR       1.725812  3.955854  168.512944  1.754124e-12  1.439258e-08
# MCRIP2      0.964274  5.891893  165.032206  2.195188e-12  1.801151e-08
#
#                p_val_adj
# ZNF341-AS1  2.232571e-09
# NFIA        2.232571e-09
# Z82244.2    2.605625e-09
# PTGIR       3.598146e-09
# MCRIP2      3.602303e-09

# %%
df2.head()
# Out:
#             logFC    logCPM          F        PValue  bonferroni  p_val_adj
# C4orf3   0.616426  7.769232  63.068401  2.753980e-08    0.000159   0.000068
# FAM162A  1.298828  6.355774  63.024569  2.771374e-08    0.000160   0.000068
# MYO1B    1.025988  5.912743  63.319447  3.561647e-08    0.000205   0.000068
# TNF      0.910981  6.178153  60.599354  5.230316e-08    0.000301   0.000075
# CGA     -1.174963  9.450181  55.583601  8.477143e-08    0.000488   0.000098

# %% [markdown]
# #  HBC

# %% [markdown]
# ### Defining a thershold for significant Up reg in HBC

# %%
df1up= df1[(df1['logFC'] > 0) ]
df1_down= df1[(df1['logFC'] < 0) ]

# %%
#df1_down['avg_log2FC']= df1_down['avg_log2FC']*-1

# %%
df1_temp = pd.concat([df1up, df1_down])

# %%
df1_temp.loc[['IL1B']]
# Out:
#          logFC     logCPM         F    PValue  bonferroni  p_val_adj
# IL1B  0.606167  12.307541  4.361408  0.047313         1.0   0.107053

# %%
# %%R
#
# library(Cairo)
# library(ggplot2)
# library(ggrepel)
# library(EnhancedVolcano)
# library(magrittr)

# %%
# %%R -i df1_temp
#
# EnhancedVolcano(df1_temp, lab = rownames(df1_temp), x="logFC", y="p_val_adj",
#                 #selectLab = c('CXCL8','IL1B'),
#
#                 pCutoff=0.05,
#                 FCcutoff = 0.1, title = "Pf_HBC", subtitle = bquote(italic(single_cell)),
#                 ylab = bquote(-Log[10] * "(p-val_adj)"), xlim = c(-2, 2), pointSize =1,
#                 labSize = 4)
# #ggsave("volcano_plot_Pf_VCT_fusing_SN_day2.eps",  device=cairo_ps, width =7,   height =7)

# %%
x= df1_temp[(df1_temp['p_val_adj'] < 0.05) ]

# %%
plt.hist(x['logFC'], bins = 100)
plt.axvline(0.1, linestyle = '--', color = 'red')
plt.axvline(-0.1, linestyle = '--', color = 'red')

# %% [markdown]
# ## Note:
# Save DEGs list:
#
#     p_val_adj < 0.05
#
#     avg_log2FC > 0.1
#
#     ==> Input to metascape

# %% [markdown]
# ### Significant Up reg in HBC

# %%
upDEG= df1[(df1['p_val_adj'] < 0.05) & (df1['logFC'] > 0.1)]

# %%
upDEG.to_csv('../results/SC_limma_Immune_MAL_24h/1_DEGs_UP_SC_MAL_24h_HBC.tsv', index=True, sep='\t')

# %%
upDEG.head()
# Out:
#                logFC    logCPM           F        PValue    bonferroni  \
# ZNF341-AS1  0.940907  3.927395  199.622904  2.783162e-13  2.283585e-09
# Z82244.2    2.443107  3.379129  178.314946  9.526965e-13  7.816875e-09
# PTGIR       1.725812  3.955854  168.512944  1.754124e-12  1.439258e-08
# MCRIP2      0.964274  5.891893  165.032206  2.195188e-12  1.801151e-08
# COL27A1     1.343494  3.982235  161.456229  2.776139e-12  2.277822e-08
#
#                p_val_adj
# ZNF341-AS1  2.232571e-09
# Z82244.2    2.605625e-09
# PTGIR       3.598146e-09
# MCRIP2      3.602303e-09
# COL27A1     3.796370e-09

# %%
#upDEG.loc[['CD44','P4HB','IL6','CSF3','CD47','DLK1']]

# %%
upDEG.shape
# Out:
# (1497, 6)

# %%
list(upDEG.index)
# Out:
# ['ZNF341-AS1',
#  'Z82244.2',
#  'PTGIR',
#  'MCRIP2',
#  'COL27A1',
#  'LINC01191',
#  'MCOLN2',
#  'AL009177.1',
#  'MFSD2A',
#  'AC007923.4',
#  'HPN-AS1',
#  'TNS1',
#  'AK4',
#  'CRIM1-DT',
#  'POR',
#  'NFKBIE',
#  'INF2',
#  'HILPDA',
#  'UPB1',
#  'HPN',
#  'GRAMD1A',
#  'FBL',
#  'MTFP1',
#  'ADM',
#  'ENO2',
#  'LY75',
#  'AL133259.1',
#  'INTS6',
#  'TNIP2',
#  'ENO1',
#  'PDGFB',
#  'AC025580.2',
#  'CYLD',
#  'GBE1',
#  'CCND1',
#  'ADORA2A-AS1',
#  'SLC48A1',
#  'ANKRD33B',
#  'TNFRSF4',
#  'AC079305.3',
#  'NDRG1',
#  'ARHGEF2',
#  'SPDYA',
#  'KCNQ1OT1',
#  'TCAF2',
#  'IRF1',
#  'PHF19',
#  'PRG2',
#  'CDC42EP5',
#  'RALGDS',
#  'TRIM36',
#  'UGP2',
#  'NEDD4L',
#  'SLC2A6',
#  'SRC',
#  'ZSWIM4',
#  'AMPD3',
#  'LINC00641',
#  'GYS1',
#  'SLC41A2',
#  'CSF1',
#  'AK2',
#  'ITGA5',
#  'ZNFX1',
#  'GPI',
#  'STC2',
#  'CDKN2B',
#  'MMP2-AS1',
#  'ABTB2',
#  'HMOX1',
#  'PARP6',
#  'CENPU',
#  'LONRF1',
#  'CTNNAL1',
#  'NFATC1',
#  'BTG3',
#  'MTMR4',
#  'UBL3',
# ...

# %% [markdown]
# ### Significant Down reg in HBC

# %%
downDEG= df1[(df1['p_val_adj'] < 0.05) & (df1['logFC'] < -0.1)]

# %%
downDEG.to_csv('../results/SC_limma_Immune_MAL_24h/1_DEGs_DOWN_SC_MAL_24h_HBC.tsv', index=True, sep='\t')

# %%
downDEG.head()
# Out:
#                logFC    logCPM           F        PValue    bonferroni  \
# NFIA       -1.279954  4.309887  187.746713  5.441978e-13  4.465143e-09
# AL137789.1 -1.308987  2.890561  144.295622  9.161531e-12  7.517036e-08
# PRKACB     -1.103440  3.438934  129.687368  2.799417e-11  2.296921e-07
# RDH10      -0.935786  4.715857  126.292756  3.684883e-11  3.023446e-07
# TM7SF3     -0.989585  3.686045  118.543877  7.068935e-11  5.800061e-07
#
#                p_val_adj
# NFIA        2.232571e-09
# AL137789.1  8.352263e-09
# PRKACB      2.088110e-08
# RDH10       2.289132e-08
# TM7SF3      3.411801e-08

# %%
downDEG.shape
# Out:
# (1340, 6)

# %%
list(downDEG.index)
# Out:
# ['NFIA',
#  'AL137789.1',
#  'PRKACB',
#  'RDH10',
#  'TM7SF3',
#  'TMC8',
#  'MIR646HG',
#  'WWOX',
#  'MS4A4A',
#  'HRH2',
#  'TDRD6',
#  'AC053513.1',
#  'WIPI1',
#  'ST6GAL1',
#  'AC079793.1',
#  'ZFP36L2',
#  'SCN1A-AS1',
#  'MRC1',
#  'PLCB2',
#  'FGL1',
#  'SLC8A1-AS1',
#  'PUS7L',
#  'PON2',
#  'GIMAP8',
#  'LRBA',
#  'SHMT1',
#  'OPHN1',
#  'REEP4',
#  'HADH',
#  'KIAA0100',
#  'TACC3',
#  'RSRC1',
#  'P2RY13',
#  'AC087273.2',
#  'TMEM236',
#  'UTRN',
#  'TMEM160',
#  'CEMIP2',
#  'PARP1',
#  'FES',
#  'HERPUD1',
#  'ODF2L',
#  'TTYH2',
#  'LMO2',
#  'MICAL2',
#  'TXNDC15',
#  'HEATR3',
#  'PGP',
#  'AL161785.1',
#  'CLDN23',
#  'C11orf65',
#  'TBC1D14',
#  'CAMKMT',
#  'ARPIN',
#  'CEP104',
#  'CCDC152',
#  'NHLRC3',
#  'MIR99AHG',
#  'NFATC3',
#  'EVI5',
#  'ANTXR2',
#  'APPL2',
#  'AC012085.2',
#  'MPEG1',
#  'TRIM37',
#  'CPB2-AS1',
#  'STARD13-AS',
#  'R3HDM1',
#  'PDSS2',
#  'SNX2',
#  'BRD7',
#  'MOB3B',
#  'PACC1',
#  'ECHDC2',
#  'CHID1',
#  'FAM53B',
#  'MGMT',
# ...

# %%
#temp= pd.read_table('../results/SC_Immune_MAL_24h/1_DEGs_DOWN_SC_MAL_24h_HBC.tsv', index_col=0)
#list(temp.index)
# Out:
# ['CGA',
#  'CPVL',
#  'FGL1',
#  'NAIP',
#  'SNX2',
#  'MS4A4A',
#  'NCF2',
#  'CABLES1',
#  'DAB2',
#  'TMEM241',
#  'SAMHD1',
#  'ARPC1B',
#  'CREM',
#  'CLEC7A',
#  'PLXDC2',
#  'RNF149',
#  'FES',
#  'SNX6',
#  'SIRPB2',
#  'MRC1',
#  'CITED2',
#  'TBC1D5',
#  'OSBPL11',
#  'CR1',
#  'MIR99AHG',
#  'OLFML2B',
#  'TBC1D14',
#  'EVI2B',
#  'IFNGR1',
#  'C1QC',
#  'MAF',
#  'WIPF1',
#  'IFIT1',
#  'PTPN22',
#  'IFI16',
#  'EVI2A',
#  'SLCO2B1',
#  'UBAC1',
#  'MX1',
#  'ARL4C',
#  'AC079793.1',
#  'NPL',
#  'EYA2',
#  'EEPD1',
#  'RAB5C',
#  'GIMAP1',
#  'WIPI1',
#  'CD14',
#  'ARHGDIB',
#  'SPTLC3',
#  'CELF2',
#  'LYL1',
#  'TRPS1',
#  'FGD4',
#  'SEMA6B',
#  'TMEM37',
#  'LPAR6',
#  'HEATR3',
#  'PGS1',
#  'ARRB2',
#  'CAPZA2',
#  'NMRK1',
#  'TMEM117',
#  'GPR34',
#  'HRH2',
#  'ANXA1',
#  'THEMIS2',
#  'GASK1B',
#  'NHLRC3',
#  'RNASE6',
#  'OSTF1',
#  'ARPC5',
#  'MX2',
#  'AL592429.2',
#  'C5AR1',
#  'TGFBI',
#  'CD200R1',
#  'ARHGAP9',
#  'OAS1',
#  'SIGLEC1',
#  'CTSZ',
# ...

# %% [markdown]
# ---

# %% [markdown]
# #  PAMM1

# %% [markdown]
# ### Significant Up reg in PAMM1

# %%
upDEG= df2[(df2['p_val_adj'] < 0.05) & (df2['logFC'] > 0.1)]

# %%
upDEG.to_csv('../results/SC_limma_Immune_MAL_24h/2_DEGs_UP_SC_MAL_24h_PAMM1.tsv', index=True, sep='\t')

# %%
upDEG.head()
# Out:
#             logFC    logCPM          F        PValue  bonferroni  p_val_adj
# C4orf3   0.616426  7.769232  63.068401  2.753980e-08    0.000159   0.000068
# FAM162A  1.298828  6.355774  63.024569  2.771374e-08    0.000160   0.000068
# MYO1B    1.025988  5.912743  63.319447  3.561647e-08    0.000205   0.000068
# TNF      0.910981  6.178153  60.599354  5.230316e-08    0.000301   0.000075
# HILPDA   1.421535  7.880796  48.940179  3.177228e-07    0.001829   0.000305

# %%
upDEG.shape
# Out:
# (167, 6)

# %%
list(upDEG.index)
# Out:
# ['C4orf3',
#  'FAM162A',
#  'MYO1B',
#  'TNF',
#  'HILPDA',
#  'ADM',
#  'SERPINE1',
#  'ERO1A',
#  'TNS1',
#  'MFSD2A',
#  'SEC61G',
#  'BNIP3',
#  'C1orf21',
#  'ENO2',
#  'LMAN1',
#  'SNX10',
#  'CCL5',
#  'ASAP1',
#  'BCL2A1',
#  'VKORC1',
#  'MXI1',
#  'FAM210A',
#  'CD300A',
#  'ADAM8',
#  'TMSB10',
#  'PPP1R14B',
#  'HMOX1',
#  'RCAN1',
#  'DUSP2',
#  'PSMB9',
#  'IL1RN',
#  'RNMT',
#  'MPC2',
#  'SLAMF9',
#  'LYRM4',
#  'IGFBP3',
#  'BHLHE40',
#  'MIF',
#  'PARVB',
#  'GADD45A',
#  'SLC41A2',
#  'HK2',
#  'WDR45B',
#  'CCNG2',
#  'INSIG2',
#  'CARD16',
#  'G0S2',
#  'C15orf48',
#  'MTFP1',
#  'SLC2A3',
#  'PIM3',
#  'TPI1',
#  'P4HA2',
#  'NDRG1',
#  'AL133453.1',
#  'ADAM28',
#  'TSC22D1',
#  'F3',
#  'AC026310.2',
#  'SAT1',
#  'TFPI2',
#  'CLEC2B',
#  'BHLHE41',
#  'C1orf122',
#  'UPP1',
#  'EIF4EBP1',
#  'SAP30',
#  'IRF1',
#  'HCST',
#  'PDXK',
#  'METTL23',
#  'IL2RG',
#  'OGA',
#  'ATF5',
#  'PRG2',
#  'DENND4A',
#  'C1orf35',
#  'LDHA',
#  'AC009630.4',
#  'JAK1',
# ...

# %% [markdown]
# ### Significant Down reg in PAMM1

# %%
downDEG= df2[(df2['p_val_adj'] < 0.05) & (df2['logFC'] < -0.1)]

# %%
downDEG.to_csv('../results/SC_limma_Immune_MAL_24h/2_DEGs_DOWN_SC_MAL_24h_PAMM1.tsv', index=True, sep='\t')

# %%
downDEG.head()
# Out:
#                logFC     logCPM          F        PValue  bonferroni  \
# CGA        -1.174963   9.450181  55.583601  8.477143e-08    0.000488
# CYP19A1    -1.408212   4.050540  40.409391  1.451004e-06    0.008355
# HSD17B1    -1.494280   5.091168  36.696942  2.531687e-06    0.014577
# FP236383.3 -0.704034  10.086739  33.469969  5.032679e-06    0.028978
# SLCO2B1    -0.819189   6.116992  31.196037  9.646780e-06    0.055546
#
#             p_val_adj
# CGA          0.000098
# CYP19A1      0.000760
# HSD17B1      0.000972
# FP236383.3   0.001704
# SLCO2B1      0.002429

# %%
downDEG.shape
# Out:
# (91, 6)

# %%
list(downDEG.index)
# Out:
# ['CGA',
#  'CYP19A1',
#  'HSD17B1',
#  'FP236383.3',
#  'SLCO2B1',
#  'KCTD12',
#  'EPAS1',
#  'HPGD',
#  'HIST1H1E',
#  'NARS',
#  'KRT18',
#  'CLTB',
#  'S100P',
#  'KRT23',
#  'TIMM13',
#  'SLC26A2',
#  'KRT8',
#  'TMEM230',
#  'NAIP',
#  'S100A12',
#  'KRCC1',
#  'GDF15',
#  'DTX3L',
#  'FUCA1',
#  'ANXA4',
#  'STRAP',
#  'APBB1IP',
#  'NRDC',
#  'B3GNT5',
#  'XAGE2',
#  'SLC40A1',
#  'TTYH3',
#  'IDH1',
#  'BRD7',
#  'TFRC',
#  'MX2',
#  'LFNG',
#  'KIAA0100',
#  'KRT19',
#  'R3HDM1',
#  'FSTL3',
#  'CASC4',
#  'TUSC2',
#  'EIF4G1',
#  'HMGB3',
#  'UBR3',
#  'MRPS15',
#  'XAGE3',
#  'PLXDC2',
#  'CDKN1C',
#  'HIST2H2AC',
#  'OSBPL11',
#  'KRT7',
#  'DERA',
#  'HNRNPAB',
#  'PHLDA2',
#  'COMMD8',
#  'UBE2E3',
#  'CENPX',
#  'CD163',
#  'ACTB',
#  'H19',
#  'TMX3',
#  'LPCAT2',
#  'PSMD1',
#  'ENG',
#  'RBM3',
#  'PARN',
#  'OLFML2B',
#  'TLR4',
#  'MEPCE',
#  'FYB1',
#  'SNX6',
#  'TNPO1',
#  'MAF',
#  'AKR1B1',
#  'AREL1',
#  'LAMP1',
#  'PAGE4',
#  'SLC30A5',
#  'GALC',
# ...
