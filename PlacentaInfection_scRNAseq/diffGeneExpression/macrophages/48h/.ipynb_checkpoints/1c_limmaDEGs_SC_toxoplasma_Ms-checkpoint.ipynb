# %% [markdown]
# **Author:** Elias Rafael Ruiz-Morales
#
# **Institution:** Wellcome Sanger institute
#
# **October, 2023**

# %% [markdown]
# ---

# %% [markdown]
# # Toxoplasma-infected vs uninfected matched explants (day1) single cell

# %%
library(limma)
library(scuttle)
library(SingleCellExperiment)
library(scater)
library(scran)
library(dplyr)
library(patchwork)
library(Seurat)
library(edgeR)
library(reshape2)
library(magrittr)

# %%
anndata <- readRDS('../../../../data_integration/48h/results/scVI/toxoplasma_singleCell_48h.rds')
anndata
# Out:
# An object of class Seurat
# 36601 features across 24479 samples within 1 assay
# Active assay: RNA (36601 features, 0 variable features)

# %%
Idents(anndata)= anndata$cell_type

# %%
head(Idents(anndata))
# Out:
# Pla_HDBR13007976_AAACCCAAGCCTCATA Pla_HDBR13007976_AAACCCAAGCTGTTAC
#                               HBC                        VCT_fusing
# Pla_HDBR13007976_AAACCCAAGGCATCAG Pla_HDBR13007976_AAACCCACACTAAACC
#                               HBC                        VCT_fusing
# Pla_HDBR13007976_AAACCCACACTACGGC Pla_HDBR13007976_AAACCCACAGCAGTCC
#                        VCT_fusing                        VCT_fusing
# 14 Levels: EVT_1 EVT_2 Endo_f F F_p HBC HBC_p PAMM1 PV VCT ... iEVT

# %% [markdown]
# # Macrophages

# %%
Mos= subset(x = anndata, idents = c("HBC","PAMM1"))

Idents(object = Mos) <- "infection"


#fixxing levels
Mos$celltype.Stage = factor(Mos$celltype.Stage, levels = c("HBC-Tg_48h", "HBC-UI_Tg_48h", "PAMM1-Tg_48h","PAMM1-UI_Tg_48h"))
Mos$cell_type<- factor(Mos$cell_type, levels = c("HBC","PAMM1"))

#The levels for the infection should follow this order to ensure that positive Fold changes correspond to increases in infection
Mos$infection<- factor(Mos$infection, levels = c("UI","Tg"))

# %%
Mos$classification = paste(Mos$cell_type, Mos$infection, sep='-') # split celltype by disease status


# estimate % cells expressing a gene in each class
plot <- DotPlot(object = Mos, features = rownames(Mos), group.by = 'classification')
plot$data$value = plot$data$pct.exp
percent_mat = acast(plot$data, features.plot ~ id)

# %%
head(percent_mat)
# Out:
#            HBC-Tg     HBC-UI     PAMM1-Tg   PAMM1-UI
# AC115284.3  0.0000000  0.0000000  0.0000000  0.0000000
# RNF186      0.0000000  0.0000000  0.0000000  0.0000000
# FMR1       38.5693431 36.5435356 26.3097950 30.7240705
# CANX       94.6277372 94.8021108 84.3963554 86.6927593
# ZNF84-DT    0.4671533  0.3166227  0.1138952  0.1956947
# LIPA       85.2262774 80.8707124 54.3280182 66.3405088

# %%
#print(Idents(VCT_fusing))

# %%
table(Mos[["celltype.Stage"]] )
# Out:
#      HBC-Tg_48h   HBC-UI_Tg_48h    PAMM1-Tg_48h PAMM1-UI_Tg_48h
#            3425            3790             878             511

# %%
anndata_sce <- as.SingleCellExperiment(Mos)

# %%
anndata_sce
# Out:
# class: SingleCellExperiment
# dim: 36601 8604
# metadata(0):
# assays(2): counts logcounts
# rownames(36601): AC115284.3 RNF186 ... PODNL1 LINC01737
# rowData names(0):
# colnames(8604): Pla_HDBR13007976_AAACCCAAGCCTCATA
#   Pla_HDBR13007976_AAACCCAAGGCATCAG ...
#   Pla_HDBR13798226_TTTGGAGCACTCCTTG Pla_HDBR13798226_TTTGGAGTCCATTGTT
# colData names(11): infection donor_id ... classification ident
# reducedDimNames(0):
# altExpNames(0):

# %% [markdown]
# ### Prepare the pseudobulk count matrix:

# %%
# generate 3 metacells for each donor-celltype combination
n=3
anndata_sce$random_seed = sample(1:n, size = ncol(anndata_sce), replace = T)
anndata_sce$metacell_id = paste( colData(anndata_sce)$infection, 
                                colData(anndata_sce)$cell_type, 
                                colData(anndata_sce)$donor_id, 
                                colData(anndata_sce)$random_seed, 
                                sep='-')
## aggregateAcrossCells here it is only aggregated by celltype, genotype and random group
summed <- aggregateAcrossCells(anndata_sce, id=colData(anndata_sce)[,c("metacell_id")])

##have a look at the counts
counts(summed)[1:3,]


#have a look at the colData of our new object summed, can you see Group and 
# metacell_id are there
# colData(summed)
table(summed$classification)
table(summed$infection)
# Out:
#            Tg-HBC-scDonor_Tg1-1 Tg-HBC-scDonor_Tg1-2 Tg-HBC-scDonor_Tg1-3
# AC115284.3   0                    0                    0
# RNF186       0                    0                    0
# FMR1       139                  157                  138
#            Tg-HBC-scDonor_Tg2-1 Tg-HBC-scDonor_Tg2-2 Tg-HBC-scDonor_Tg2-3
# AC115284.3   0                    0                    0
# RNF186       0                    0                    0
# FMR1       160                  190                  191
#            Tg-HBC-scDonor_Tg3-1 Tg-HBC-scDonor_Tg3-2 Tg-HBC-scDonor_Tg3-3
# AC115284.3   0                    0                    0
# RNF186       0                    0                    0
# FMR1       157                  125                  117
#            Tg-HBC-scDonor_Tg4-1 ⋯ UI-PAMM1-scDonor_Tg1-3 UI-PAMM1-scDonor_Tg2-1
# AC115284.3   0                  ⋯ 0                      0
# RNF186       0                  ⋯ 0                      0
# FMR1       146                  ⋯ 1                      5
#            UI-PAMM1-scDonor_Tg2-2 UI-PAMM1-scDonor_Tg2-3 UI-PAMM1-scDonor_Tg3-1
# AC115284.3 0                      0                       0
# RNF186     0                      0                       0
# FMR1       3                      8                      54
#            UI-PAMM1-scDonor_Tg3-2 UI-PAMM1-scDonor_Tg3-3 UI-PAMM1-scDonor_Tg4-1
# AC115284.3  0                      0                     0
# RNF186      0                      0                     0
# FMR1       56                     59                     6
#            UI-PAMM1-scDonor_Tg4-2 UI-PAMM1-scDonor_Tg4-3
# AC115284.3 0                      0
# RNF186     0                      0
# FMR1       9                      3
#   HBC-Tg   HBC-UI PAMM1-Tg PAMM1-UI
#       12       12       12       12
# UI Tg
# 24 24

# %%
summed
# Out:
# class: SingleCellExperiment
# dim: 36601 48
# metadata(0):
# assays(1): counts
# rownames(36601): AC115284.3 RNF186 ... PODNL1 LINC01737
# rowData names(0):
# colnames(48): Tg-HBC-scDonor_Tg1-1 Tg-HBC-scDonor_Tg1-2 ...
#   UI-PAMM1-scDonor_Tg4-2 UI-PAMM1-scDonor_Tg4-3
# colData names(15): infection donor_id ... ids ncells
# reducedDimNames(0):
# altExpNames(0):

# %%
summed$infection<- factor(summed$infection, levels = c( "UI","Tg"))

# %%
table(summed$infection)
# Out:
# UI Tg
# 24 24

# %% [markdown]
# ### Corrected by genotype

# %%
DEGs_list = list()

# %%
for (celltypeOf_interest in unique(summed$cell_type) ){
    
    #celltypeOf_interest = 'VCT'
    print(celltypeOf_interest)

    # (0) Subset to celltype
    summed_celltype = subset(summed, , summed$cell_type == celltypeOf_interest)


    # (1) Generate a DGEList object to use as input for limma and filter the genes to remove lowly expressed genes. How many are left?
    #As in the standard limma analysis generate a DGE object
    y <- DGEList(counts(summed_celltype), samples=colData(summed_celltype)$metacell_id)

    ##filter lowly expressed (recommended for limma)
    #     keep <- filterByExpr(y, group=summed_celltype$dataset, min.total.count = 3000, min.prop = 0.1)
    keep <- filterByExpr(y, group=summed_celltype$donor_id, min.prop = 0.2)

    genes20percent = rownames(percent_mat)[ apply(percent_mat[, unique(summed_celltype$classification) ], 1, max) > 20 ] # get genes with > 20% expressed cells in the celltypeOf_interest
    keep <- keep & names(keep) %in% genes20percent
    y <- y[ keep ,]



    # (2) Perform TMM normalization using edgeR, and then limma can perform the transformation with voom, fit the model, compute the contrasts and compute test statistics with eBayes:
    y <- edgeR::calcNormFactors(y)


    ##see how many genes were kept 
    summary(keep)


    # (3) Generate a design matrix, including dataset to model for a paired analysis. 
    # If you need help to generate a design matrix, check out the very nice edgeR User Guide, sections 3.3 and 3.4. 
    ## Create the design matrix for paired samples while correcting for the effect of the donor to obtain
    #  the overall effect of the infection across donors:
    design <- model.matrix(~summed_celltype$donor_id+summed_celltype$infection)
        # stimate dispersion
    y <- estimateDisp(y,design)
        # Have a look
    head(design)


    # (4) Do limma DEG
    fit <- glmQLFit(y, design)
    qlf <- glmQLFTest(fit)
    topTags(qlf)

    ##  Adjust P values using bonferroni and BH
    limma_de = qlf$table
    limma_de$bonferroni = p.adjust(limma_de$PValue, "bonferroni")
    limma_de$p_val_adj = p.adjust(limma_de$PValue, "BH")
        
    # order table by P-value
    limma_de= limma_de[ order(limma_de$p_val_adj, decreasing = FALSE), ]
    #limma_de <- order(limma_de$p.adjust, decreasing = FALSE)
    #imma_de = limma_de.sort_values('p.adjust', ascending = TRUE)

    # Adding to the list
    DEGs_list[[celltypeOf_interest]] = limma_de
}
# Out:
# [1] "HBC"
# [1] "PAMM1"

# %%
##  Saving the DEG matrix

write.table(DEGs_list[["HBC"]],'../results/SC_limma_Immune_TOX_48h/1_DEGs_SC_TOX_48h_HBC.tsv',sep = '\t',quote = FALSE,row.names = TRUE,col.names = NA)
write.table(DEGs_list[["PAMM1"]],'../results/SC_limma_Immune_TOX_48h/2_DEGs_SC_TOX_48h_PAMM1.tsv',sep = '\t',quote = FALSE,row.names = TRUE,col.names = NA)

# %%
#colData(summed_celltype)$metacell_id

# %%
plotBCV(y)
# Out:
# plot without title

# %%
plotQLDisp(fit)
# Out:
# plot without title

# %%
o <- order(qlf$table$PValue)
cpm(y)[o[1:20],]
# Out:
#          Tg-PAMM1-scDonor_Tg1-1 Tg-PAMM1-scDonor_Tg1-2 Tg-PAMM1-scDonor_Tg1-3
# IFIT2       0.000000              4.865853               5.445618
# LRRC8B     39.882836             24.329266              24.505283
# CGA       478.594034            467.121905             707.930396
# IFIT1       0.000000             14.597560               8.168428
# AKT3       63.812538             82.719504              76.238658
# EGFL7       7.976567             29.195119               8.168428
# FNDC3A    342.992391            291.951190             364.856435
# TMEM38B   223.343883            170.304861             171.536981
# IFITM2     39.882836             38.926825              29.950901
# FOLR2       7.976567              4.865853               0.000000
# MS4A6A     23.929702             19.463413              43.564947
# PTP4A2     15.953134             24.329266              32.673711
# KYNU     1332.086728            715.280416             903.972659
# GPHN      167.507912            107.048770             100.743941
# CMPK2      23.929702             14.597560              19.059665
# BTG2       31.906269             34.060972              35.396520
# MPEG1      55.835971             77.853651              38.119329
# VCAN-AS1   15.953134             14.597560               2.722809
# LST1       47.859403             82.719504              73.515849
# HSPA8      71.789105            218.963393             174.259790
#          Tg-PAMM1-scDonor_Tg2-1 Tg-PAMM1-scDonor_Tg2-2 Tg-PAMM1-scDonor_Tg2-3
# IFIT2     10.59010                4.243263               5.585638
# LRRC8B    15.88515               28.288418              24.204429
# CGA      499.49974              325.316806             450.574762
# IFIT1     17.65017               15.558630              26.066309
# AKT3     109.43104              100.423884              85.646442
# EGFL7     22.94522               11.315367               9.309396
# FNDC3A   525.97499              571.426042             586.491942
# TMEM38B   95.31090              100.423884              96.817717
# IFITM2    79.42575               65.063361              70.751409
# FOLR2     15.88515               22.630734              20.480671
# MS4A6A    45.89044               93.351779              44.685100
# PTP4A2    33.53532               32.531681              26.066309
# KYNU     450.07927              555.867412             811.779322
# GPHN     162.38154               57.991257             102.403355
# CMPK2      5.29505               15.558630              13.033154
# BTG2      61.77559               49.504731              52.132617
# MPEG1     79.42575               79.207570             113.574630
# VCAN-AS1  63.54060               45.261469              55.856375
# LST1     107.66602               97.595042              96.817717
# HSPA8     90.01585              118.811355             130.331543
#          Tg-PAMM1-scDonor_Tg3-1 Tg-PAMM1-scDonor_Tg3-2 Tg-PAMM1-scDonor_Tg3-3
# IFIT2     26.74459               20.10731               23.64102
# LRRC8B    28.65492               30.16097               27.47470
# CGA      389.07017              303.15644              454.29100
# IFIT1     50.30531               27.06754               33.86417
# AKT3     113.98291              120.64389              122.03879
# EGFL7     11.46197               10.82702               10.86209
# FNDC3A   379.51853              432.30726              360.36586
# TMEM38B  105.70483               95.12307               83.06305
# IFITM2    23.56071               24.74746               35.78101
# FOLR2     33.74913               33.25440               43.44837
# MS4A6A   112.07259               88.93620              123.31668
# PTP4A2    42.66400               39.44127               42.80942
# KYNU     659.06322              806.61266              716.89803
# GPHN     136.90685              146.93807              120.12195
# CMPK2     29.29170               20.88067               28.11365
# BTG2      84.05444               49.49493               65.81150
# MPEG1     71.31892               75.78911               86.25778
# VCAN-AS1  37.56979               40.98799               48.55994
# LST1      94.24286              109.04351               98.39777
# HSPA8    108.25193               86.61612               96.48093
#          Tg-PAMM1-scDonor_Tg4-1 ⋯ UI-PAMM1-scDonor_Tg1-3 UI-PAMM1-scDonor_Tg2-1
# IFIT2     15.905848             ⋯    0.000000             12.605133
# LRRC8B    52.395734             ⋯   23.949686              6.302566
# CGA      363.963224             ⋯  255.463322            308.825753
# IFIT1     26.197867             ⋯   15.966458             25.210266
# AKT3     137.538802             ⋯   31.932915             63.025664
# EGFL7     13.098934             ⋯    7.983229              6.302566
# FNDC3A   575.417437             ⋯  263.446550            447.482214
# TMEM38B   64.559029             ⋯  119.748432             63.025664
# IFITM2    27.133505             ⋯   39.916144             94.538496
# FOLR2     13.098934             ⋯   47.899373             18.907699
# MS4A6A    77.657963             ⋯   47.899373            107.143629
# PTP4A2    33.682972             ⋯   23.949686             12.605133
# KYNU     979.613099             ⋯  654.624762            390.759117
# GPHN      98.242001             ⋯   47.899373             63.025664
# CMPK2      7.485105             ⋯    0.000000              0.000000
# BTG2      58.945201             ⋯   31.932915             94.538496
# MPEG1     56.138286             ⋯   31.932915            107.143629
# VCAN-AS1  24.326591             ⋯   23.949686              6.302566
# LST1      74.851049             ⋯   55.882602            170.169293
# HSPA8    103.855830             ⋯ 1029.836515            100.841062
#          UI-PAMM1-scDonor_Tg2-2 UI-PAMM1-scDonor_Tg2-3 UI-PAMM1-scDonor_Tg3-1
# IFIT2      0.00000                6.949047              73.37555
# LRRC8B    33.58608                6.949047              13.68947
# CGA      447.81444              326.605220             220.12664
# IFIT1      0.00000               13.898094              90.35049
# AKT3      55.97681               97.286661              83.77954
# EGFL7     67.17217               27.796189              24.09346
# FNDC3A   526.18197              347.452361             326.35691
# TMEM38B  100.75825               41.694283              59.13850
# IFITM2    44.78144               76.439520              58.59092
# FOLR2     55.97681               62.541425              50.37724
# MS4A6A    33.58608              166.777133             113.89637
# PTP4A2    33.58608               13.898094              32.30714
# KYNU     358.25155              173.726181             665.30812
# GPHN      78.36753               34.745236             114.44395
# CMPK2      0.00000                6.949047              60.23366
# BTG2      22.39072              222.369511              75.01828
# MPEG1    123.14897              125.082850             139.63257
# VCAN-AS1  44.78144               13.898094              99.11175
# LST1      78.36753              194.573322             130.32373
# HSPA8    145.53969              187.624275             110.61090
#          UI-PAMM1-scDonor_Tg3-2 UI-PAMM1-scDonor_Tg3-3 UI-PAMM1-scDonor_Tg4-1
# IFIT2     96.48788               73.97934                0.00000
# LRRC8B    11.21952               16.73985               32.39057
# CGA      195.78065              240.29785              172.74968
# IFIT1    103.78057              115.01897               16.19528
# AKT3      87.51227               85.85923               86.37484
# EGFL7     19.63416               24.29978               43.18742
# FNDC3A   307.41489              286.73743              431.87420
# TMEM38B   71.80494               92.33917               37.78899
# IFITM2    61.70737               70.19937               59.38270
# FOLR2     46.00004               70.73937               48.58585
# MS4A6A   140.24402              165.77852              156.55440
# PTP4A2    23.56100               29.15974               21.59371
# KYNU     537.41508              723.59352              572.23332
# GPHN      70.68299              104.75906              113.36698
# CMPK2     60.58542               54.53951               26.99214
# BTG2      89.75617               77.21931              124.16383
# MPEG1    138.00011              127.43886               70.17956
# VCAN-AS1  94.80496               81.53927               43.18742
# LST1     134.63426              114.47898               97.17170
# HSPA8    118.92693              134.99879              156.55440
#          UI-PAMM1-scDonor_Tg4-2 UI-PAMM1-scDonor_Tg4-3
# IFIT2     10.345441               0.000000
# LRRC8B    15.518162              30.075724
# CGA      227.599702             300.757235
# IFIT1     25.863603               7.518931
# AKT3     118.972572             135.340756
# EGFL7     36.209044              22.556793
# FNDC3A   367.263156             300.757235
# TMEM38B   20.690882              30.075724
# IFITM2    46.554485              15.037862
# FOLR2     67.245367              30.075724
# MS4A6A   212.081541              90.227171
# PTP4A2    25.863603              22.556793
# KYNU     651.762784             759.412020
# GPHN      82.763528              75.189309
# CMPK2      5.172721               7.518931
# BTG2     170.699777             150.378618
# MPEG1     82.763528              97.746102
# VCAN-AS1 103.454410             135.340756
# LST1     108.627131              90.227171
# HSPA8    170.699777             105.265032

# %%
summary(decideTests(qlf))
# Out:
#        summed_celltype$infectionTg
# Down                             2
# NotSig                        6306
# Up                               2

# %%
plotMD(qlf)
abline(h=c(-1, 1), col="blue")
# Out:
# Plot with title “summed_celltype$infectionTg”

# %%
limma_de = qlf$table
limma_de$bonferroni = p.adjust(limma_de$PValue, "bonferroni")
limma_de$BH = p.adjust(limma_de$PValue, "BH")

hist(limma_de$PValue)
# Out:
# Plot with title “Histogram of limma_de$PValue”

# %%
library(ggplot2, warn.conflicts = FALSE)
ggplot(limma_de, aes(x = logFC, y = - log10(PValue))) +
  geom_point(aes(color = bonferroni < 0.05), size = 0.5) + 
    theme_light()  + 
    coord_fixed(ratio = 0.75)
# Out:
# plot without title

# %%
ggplot(limma_de, aes(x = logFC, y = - log10(PValue))) +
  geom_point(aes(color = BH < 0.05), size = 0.5) + 
    theme_light()  + 
    coord_fixed(ratio = 0.75)
# Out:
# plot without title

# %%
sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/blas/libblas.so.3.9.0
# LAPACK: /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3.9.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] magrittr_2.0.3              reshape2_1.4.4
#  [3] edgeR_3.32.1                SeuratObject_4.0.0
#  [5] Seurat_4.0.1                patchwork_1.1.1
#  [7] dplyr_1.0.5                 scran_1.18.5
#  [9] scater_1.18.6               ggplot2_3.3.6
# [11] scuttle_1.0.4               SingleCellExperiment_1.12.0
# [13] SummarizedExperiment_1.20.0 Biobase_2.50.0
# [15] GenomicRanges_1.42.0        GenomeInfoDb_1.26.4
# [17] IRanges_2.24.1              S4Vectors_0.28.1
# [19] BiocGenerics_0.36.1         MatrixGenerics_1.2.1
# [21] matrixStats_1.0.0           limma_3.46.0
#
# loaded via a namespace (and not attached):
#   [1] uuid_0.1-4                plyr_1.8.6
#   [3] igraph_1.2.6              repr_1.1.3
#   [5] lazyeval_0.2.2            splines_4.0.4
#   [7] BiocParallel_1.24.1       listenv_0.8.0
#   [9] scattermore_0.7           digest_0.6.33
#  [11] htmltools_0.5.1.1         viridis_0.5.1
#  [13] fansi_1.0.4               tensor_1.5
#  [15] cluster_2.1.1             ROCR_1.0-11
#  [17] globals_0.14.0            spatstat.sparse_2.0-0
#  [19] colorspace_2.1-0          ggrepel_0.9.1
#  [21] crayon_1.5.2              RCurl_1.98-1.12
#  [23] jsonlite_1.8.7            spatstat.data_2.1-0
#  [25] survival_3.2-10           zoo_1.8-9
#  [27] glue_1.6.2                polyclip_1.10-4
#  [29] gtable_0.3.0              zlibbioc_1.36.0
#  [31] XVector_0.30.0            leiden_0.3.7
#  [33] DelayedArray_0.16.3       BiocSingular_1.6.0
#  [35] future.apply_1.7.0        abind_1.4-5
#  [37] scales_1.1.1              DBI_1.1.1
#  [39] miniUI_0.1.1.1            Rcpp_1.0.11
#  [41] viridisLite_0.4.2         xtable_1.8-4
#  [43] reticulate_1.18           spatstat.core_1.65-5
#  [45] dqrng_0.2.1               rsvd_1.0.5
#  [47] htmlwidgets_1.5.3         httr_1.4.2
#  [49] RColorBrewer_1.1-3        ellipsis_0.3.1
#  [51] ica_1.0-2                 pkgconfig_2.0.3
#  [53] uwot_0.1.10               deldir_1.0-6
#  [55] locfit_1.5-9.4            utf8_1.2.3
#  [57] tidyselect_1.1.0          rlang_1.1.1
#  [59] later_1.1.0.1             munsell_0.5.0
#  [61] tools_4.0.4               cli_3.6.1
#  [63] generics_0.1.3            ggridges_0.5.3
#  [65] evaluate_0.21             stringr_1.4.0
#  [67] fastmap_1.1.1             goftest_1.2-2
#  [69] fitdistrplus_1.1-3        purrr_0.3.4
#  [71] RANN_2.6.1                nlme_3.1-152
#  [73] pbapply_1.4-3             future_1.21.0
#  [75] sparseMatrixStats_1.2.1   mime_0.12
#  [77] compiler_4.0.4            beeswarm_0.4.0
#  [79] plotly_4.9.3              png_0.1-8
#  [81] spatstat.utils_2.3-1      tibble_3.1.0
#  [83] statmod_1.4.35            stringi_1.7.12
#  [85] lattice_0.20-41           bluster_1.0.0
#  [87] IRdisplay_1.0             Matrix_1.3-2
#  [89] vctrs_0.3.6               pillar_1.5.1
#  [91] lifecycle_1.0.3           spatstat.geom_2.4-0
#  [93] lmtest_0.9-38             RcppAnnoy_0.0.18
#  [95] BiocNeighbors_1.8.2       data.table_1.14.0
#  [97] cowplot_1.1.1             bitops_1.0-7
#  [99] irlba_2.3.5.1             httpuv_1.5.5
# [101] R6_2.5.1                  promises_1.2.0.1
# [103] KernSmooth_2.23-18        gridExtra_2.3
# [105] vipor_0.4.5               parallelly_1.24.0
# [107] codetools_0.2-18          MASS_7.3-53.1
# [109] assertthat_0.2.1          withr_2.5.0
# [111] sctransform_0.3.2         GenomeInfoDbData_1.2.4
# [113] mgcv_1.8-34               rpart_4.1-15
# [115] grid_4.0.4                beachmat_2.6.4
# [117] IRkernel_1.1.1            tidyr_1.1.3
# [119] DelayedMatrixStats_1.12.3 Rtsne_0.15
# [121] pbdZMQ_0.3-5              shiny_1.6.0
# [123] base64enc_0.1-3           ggbeeswarm_0.6.0
