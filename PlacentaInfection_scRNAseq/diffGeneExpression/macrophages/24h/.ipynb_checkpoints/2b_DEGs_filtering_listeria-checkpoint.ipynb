# %% [markdown]
# **Author:** Elias Rafael Ruiz-Morales
#
# **Institution:** Wellcome Sanger institute
#
# **July, 2023**

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import os
import sys
import scipy

import matplotlib.pyplot as plt

import seaborn as sns
import scanpy as sc

# %% [markdown]
# ### Note
# To run this chunk you need:
#
# *rpy2==3.4.2  ///  anndata2ri==1.0.6*

# %%
import rpy2.robjects as ro
import rpy2.robjects.numpy2ri

import rpy2.rinterface_lib.callbacks
import logging
# Itoliste R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)
import anndata2ri
anndata2ri.activate()
# %load_ext rpy2.ipython

# %% [markdown]
# ## Load subset Listeria 24H post-infection

# %%
adata= sc.read('../../../data_integration/results/scVI/listeria_singleCell_24h.h5ad')

# %% [markdown]
# #### Subset immune cells

# %%
adata =adata[[ i in ['HBC','HBC_p','PAMM1'] for i in adata.obs.cell_type ]]
adata.write ('../data/listeria_singleCell_24h_Immune.h5ad')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
del(adata)

# %% [markdown]
# # Filtering DEGs

# %%
df1 = pd.read_csv('../results/SC_limma_Immune_LIS_24h/1_DEGs_SC_LIS_24h_HBC.tsv', index_col=0,sep='\t')
df2 = pd.read_csv('../results/SC_limma_Immune_LIS_24h/2_DEGs_SC_LIS_24h_PAMM1.tsv', index_col=0,sep='\t')

# %%
df1.head()
# Out:
#             logFC    logCPM           F        PValue    bonferroni  \
# STC1     1.288401  6.197037  242.503878  3.226768e-13  2.358122e-09
# IL1RN    1.022193  7.355690  222.829592  7.465613e-13  5.455870e-09
# IGFBP4  -0.627356  6.728119  177.960289  6.730971e-12  4.918994e-08
# ATP13A3  0.468337  7.538326  159.872988  1.887261e-11  1.379211e-07
# FCGRT   -0.369558  9.378415  151.271960  3.197164e-11  2.336487e-07
#
#             p_val_adj
# STC1     2.358122e-09
# IL1RN    2.727935e-09
# IGFBP4   1.639665e-08
# ATP13A3  3.448026e-08
# FCGRT    4.672975e-08

# %%
df2.head()
# Out:
#              logFC     logCPM          F        PValue  bonferroni  p_val_adj
# C15orf48  1.144871   9.545963  88.965254  7.574555e-10    0.000005   0.000005
# STC1      1.372473   5.604870  80.251079  2.121684e-09    0.000013   0.000006
# C1orf56   1.185322   5.357605  62.887467  2.195464e-08    0.000134   0.000045
# TIMP1     0.744604  10.769514  57.788443  4.768015e-08    0.000290   0.000058
# MARCKS    0.597890   9.892981  58.744905  4.107608e-08    0.000250   0.000058

# %% [markdown]
# #  HBC

# %%
df1up= df1[(df1['logFC'] > 0) ]
df1_down= df1[(df1['logFC'] < 0) ]

# %%
#df1_down['avg_log2FC']= df1_down['avg_log2FC']*-1
df1_temp = pd.concat([df1up, df1_down])

# %%
df1_temp
# Out:
#                logFC    logCPM           F        PValue    bonferroni  \
# STC1        1.288401  6.197037  242.503878  3.226768e-13  2.358122e-09
# IL1RN       1.022193  7.355690  222.829592  7.465613e-13  5.455870e-09
# ATP13A3     0.468337  7.538326  159.872988  1.887261e-11  1.379211e-07
# SAMSN1      0.451065  8.824758  130.151077  1.316877e-10  9.623734e-07
# AL360227.1  0.779019  4.882505  126.551758  1.709469e-10  1.249280e-06
# ...              ...       ...         ...           ...           ...
# DIS3L2     -0.000191  5.607963    0.000013  9.972058e-01  1.000000e+00
# ZNF496     -0.003106  3.871479    0.001814  9.974783e-01  1.000000e+00
# KHDRBS1    -0.000124  6.473891    0.000009  9.976239e-01  1.000000e+00
# STK17B     -0.000118  6.717451    0.000005  9.982881e-01  1.000000e+00
# THUMPD3    -0.000173  4.767530    0.000004  9.983336e-01  1.000000e+00
#
#                p_val_adj
# STC1        2.358122e-09
# IL1RN       2.727935e-09
# ATP13A3     3.448026e-08
# ...

# %%
# %%R
#
# library(Cairo)
# library(ggplot2)
# library(ggrepel)
# library(EnhancedVolcano)
# library(magrittr)

# %%
# %%R -i df1_temp
#
# EnhancedVolcano(df1_temp, lab = rownames(df1_temp), x="logFC", y="p_val_adj",
#                 #selectLab = c('CXCL8','IL1B'),
#
#                 pCutoff=0.05,
#                 FCcutoff = 0.1, title = "Lm_HBC", subtitle = bquote(italic(single_cell)),
#                 ylab = bquote(-Log[10] * "(p-val_adj)"), xlim = c(-1, 1), pointSize =1,
#                 labSize = 4)
# #ggsave("volcano_plot_Pf_VCT_fusing_SN_day2.eps",  device=cairo_ps, width =7,   height =7)

# %%
x= df1_temp[(df1_temp['p_val_adj'] < 0.05) ]

# %%
plt.hist(x['logFC'], bins = 100)
plt.axvline(0.1, linestyle = '--', color = 'red')
plt.axvline(-0.1, linestyle = '--', color = 'red')

# %% [markdown]
# ## Note:
# Save DEGs list:
#
#     p_val_adj < 0.05
#
#     avg_log2FC > 0.1
#
#     ==> Input to metascape

# %% [markdown]
# ### Significant Up reg in HBC

# %%
upDEG= df1[(df1['p_val_adj'] < 0.05) & (df1['logFC'] > 0.1)]

# %%
upDEG.to_csv('../results/SC_limma_Immune_LIS_24h/1_DEGs_UP_SC_LIS_24h_HBC.tsv', index=True, sep='\t')

# %%
upDEG.head()
# Out:
#                logFC    logCPM           F        PValue    bonferroni  \
# STC1        1.288401  6.197037  242.503878  3.226768e-13  2.358122e-09
# IL1RN       1.022193  7.355690  222.829592  7.465613e-13  5.455870e-09
# ATP13A3     0.468337  7.538326  159.872988  1.887261e-11  1.379211e-07
# SAMSN1      0.451065  8.824758  130.151077  1.316877e-10  9.623734e-07
# AL360227.1  0.779019  4.882505  126.551758  1.709469e-10  1.249280e-06
#
#                p_val_adj
# STC1        2.358122e-09
# IL1RN       2.727935e-09
# ATP13A3     3.448026e-08
# SAMSN1      1.374819e-07
# AL360227.1  1.388089e-07

# %%
upDEG.loc[['AREG','MIF','CD44']]
# Out:
#          logFC    logCPM          F        PValue  bonferroni     p_val_adj
# AREG  0.586724  5.904736  89.241613  4.022578e-09    0.000029  7.745239e-07
# MIF   0.588840  9.631332  56.473617  1.854347e-07    0.001355  8.836809e-06
# CD44  0.453737  9.018105  78.192604  1.264909e-08    0.000092  1.698926e-06

# %%
upDEG.shape
# Out:
# (1188, 6)

# %%
list(upDEG.index)
# Out:
# ['STC1',
#  'IL1RN',
#  'ATP13A3',
#  'SAMSN1',
#  'AL360227.1',
#  'S100A8',
#  'TLNRD1',
#  'EIF1B',
#  'VCAN',
#  'CXCL2',
#  'MXD1',
#  'IL1A',
#  'ITGB1',
#  'P4HA1',
#  'PTGS2',
#  'IL1B',
#  'C15orf48',
#  'SERPINE1',
#  'CYP1B1',
#  'HES1',
#  'EGR1',
#  'CCL4',
#  'ABCA1',
#  'VEGFA',
#  'PCNX1',
#  'AREG',
#  'CPB2-AS1',
#  'TULP2',
#  'TNIK',
#  'AL133453.1',
#  'GK-AS1',
#  'LILRB2',
#  'SLC41A2',
#  'NT5E',
#  'AC008771.1',
#  'AC066613.2',
#  'CTNNB1',
#  'CD44',
#  'FOSL2',
#  'BTG1',
#  'BNIP3L',
#  'CCL3',
#  'PNRC1',
#  'CXCL1',
#  'NLRP3',
#  'LILRB1',
#  'SOD2',
#  'AC098829.1',
#  'TFPI2',
#  'SEC61G',
#  'SYF2',
#  'LRP12',
#  'LINC00513',
#  'AP003086.1',
#  'DYSF',
#  'SERPINB9',
#  'LGALS1',
#  'KYNU',
#  'TIMP3',
#  'ARL6IP1',
#  'DUSP4',
#  'LUCAT1',
#  'CNIH4',
#  'RND3',
#  'BTG3',
#  'WTAP',
#  'MTF1',
#  'LINC01619',
#  'AC112253.1',
#  'MAFB',
#  'PLAUR',
#  'AC104365.1',
#  'AQP9',
#  'CCL20',
#  'ALOX5AP',
#  'CXCL3',
#  'GLUL',
#  'DLEU7',
# ...

# %%
#list(upDEG.index)

# %% [markdown]
# ### Significant Down reg in HBC

# %%
downDEG= df1[(df1['p_val_adj'] < 0.05) & (df1['logFC'] < -0.1)]

# %%
downDEG.to_csv('../results/SC_limma_Immune_LIS_24h/1_DEGs_DOWN_SC_LIS_24h_HBC.tsv', index=True, sep='\t')

# %%
downDEG.head()
# Out:
#            logFC    logCPM           F        PValue    bonferroni  \
# IGFBP4 -0.627356  6.728119  177.960289  6.730971e-12  4.918994e-08
# FCGRT  -0.369558  9.378415  151.271960  3.197164e-11  2.336487e-07
# TUBA1B -0.400084  8.266948  131.965491  1.157299e-10  8.457541e-07
# BIN1   -0.565812  4.881556  127.614778  1.581642e-10  1.155864e-06
# PEBP1  -0.343432  7.751746  112.263480  5.150756e-10  3.764172e-06
#
#            p_val_adj
# IGFBP4  1.639665e-08
# FCGRT   4.672975e-08
# TUBA1B  1.374819e-07
# BIN1    1.388089e-07
# PEBP1   2.141862e-07

# %%
downDEG.shape
# Out:
# (1209, 6)

# %%
list(downDEG.index)
# Out:
# ['IGFBP4',
#  'FCGRT',
#  'TUBA1B',
#  'BIN1',
#  'PEBP1',
#  'C1QC',
#  'CPVL',
#  'PEPD',
#  'NAV3',
#  'CSF1R',
#  'TUBA1A',
#  'SHMT1',
#  'BLVRB',
#  'CALR',
#  'BST2',
#  'EPHX1',
#  'APRT',
#  'KLF2',
#  'DNAJB11',
#  'GLIPR1',
#  'LYVE1',
#  'PDIA4',
#  'FIS1',
#  'HPGDS',
#  'RRP12',
#  'GAMT',
#  'MIR646HG',
#  'MS4A4A',
#  'SRXN1',
#  'ISOC2',
#  'C2',
#  'DNPH1',
#  'PRDX1',
#  'S100A4',
#  'FCGR3A',
#  'FEZ1',
#  'FOLR2',
#  'C1QA',
#  'CTSD',
#  'LINC02306',
#  'DISC1',
#  'LGMN',
#  'INPP4B',
#  'ABLIM3',
#  'PCDH12',
#  'TMEM14C',
#  'CHCHD10',
#  'TACC3',
#  'TTYH3',
#  'PLTP',
#  'NAV2',
#  'GAS7',
#  'SLC27A4',
#  'LIMCH1',
#  'ADGRE5',
#  'MS4A6A',
#  'AARS',
#  'HSPA4',
#  'CTTNBP2',
#  'PARP1',
#  'NDUFS6',
#  'FAM20A',
#  'LAMP1',
#  'SDHC',
#  'CST3',
#  'GRN',
#  'CD180',
#  'FAM53B',
#  'CLN6',
#  'LSM4',
#  'GAS6',
#  'AMDHD2',
#  'TESC',
#  'F13A1',
#  'CD74',
#  'LAMTOR2',
#  'MRPS34',
#  'SCPEP1',
#  'COMT',
#  'QDPR',
#  'FOSB',
#  'TM2D2',
#  'LAP3',
# ...

# %% [markdown]
# ---

# %% [markdown]
# #  PAMM1

# %% [markdown]
# ### Significant Up reg in PAMM1

# %%
upDEG= df2[(df2['p_val_adj'] < 0.05) & (df2['logFC'] > 0.1)]

# %%
upDEG.to_csv('../results/SC_limma_Immune_LIS_24h/2_DEGs_UP_SC_LIS_24h_PAMM1.tsv', index=True, sep='\t')

# %%
upDEG.head()
# Out:
#              logFC     logCPM          F        PValue  bonferroni  p_val_adj
# C15orf48  1.144871   9.545963  88.965254  7.574555e-10    0.000005   0.000005
# STC1      1.372473   5.604870  80.251079  2.121684e-09    0.000013   0.000006
# C1orf56   1.185322   5.357605  62.887467  2.195464e-08    0.000134   0.000045
# TIMP1     0.744604  10.769514  57.788443  4.768015e-08    0.000290   0.000058
# MARCKS    0.597890   9.892981  58.744905  4.107608e-08    0.000250   0.000058

# %%
upDEG.shape
# Out:
# (157, 6)

# %%
list(upDEG.index)
# Out:
# ['C15orf48',
#  'STC1',
#  'C1orf56',
#  'TIMP1',
#  'MARCKS',
#  'SLC30A4',
#  'SOD2',
#  'CCL5',
#  'CPB2-AS1',
#  'SERPINB9',
#  'SERPINA1',
#  'RNF175',
#  'TIMP3',
#  'MT2A',
#  'SAT1',
#  'PRG2',
#  'ITGB1',
#  'NCF1',
#  'TFPI2',
#  'SOX5',
#  'TNFAIP6',
#  'PPFIBP1',
#  'IL2RA',
#  'ITGA2',
#  'IL1B',
#  'MMP9',
#  'CTSH',
#  'WNT5A',
#  'SNX10',
#  'AC025580.2',
#  'CD82',
#  'NBN',
#  'EIF1B',
#  'CCL3',
#  'ACO1',
#  'GK-AS1',
#  'AL133453.1',
#  'SLC16A7',
#  'BTG3',
#  'CD93',
#  'CD48',
#  'P4HA1',
#  'INHBA',
#  'LILRB1',
#  'TM4SF1',
#  'CXCL8',
#  'LIMK2',
#  'LYN',
#  'SLC25A37',
#  'CXCL1',
#  'CCL3L1',
#  'CNIH4',
#  'LCP1',
#  'IL2RG',
#  'IGFBP5',
#  'MMP14',
#  'IL1A',
#  'MT1F',
#  'EFL1',
#  'AC009630.1',
#  'DYSF',
#  'CXCL5',
#  'MT1E',
#  'AC066613.2',
#  'FCER1G',
#  'WTAP',
#  'AC007319.1',
#  'IPO9-AS1',
#  'GLIS3',
#  'SEPTIN10',
#  'APH1B',
#  'TLR2',
#  'CCL20',
#  'CXCL2',
#  'METTL9',
#  'MTHFD2L',
#  'SLC7A7',
#  'CALM1',
#  'IL1RN',
#  'MRPL52',
# ...

# %% [markdown]
# ### Significant Down reg in PAMM1

# %%
downDEG= df2[(df2['p_val_adj'] < 0.05) & (df2['logFC'] < -0.1)]

# %%
downDEG.to_csv('../results/SC_limma_Immune_LIS_24h/2_DEGs_DOWN_SC_LIS_24h_PAMM1.tsv', index=True, sep='\t')

# %%
downDEG.head()
# Out:
#                logFC     logCPM          F        PValue  bonferroni  \
# LDLRAD4    -0.760691   6.355928  47.002309  2.923840e-07    0.001780
# FPR3       -0.882581   6.105743  44.779665  4.396464e-07    0.002677
# RNASE1     -0.642843  10.702787  41.210765  8.708442e-07    0.005302
# MIR181A1HG -0.558460   6.588696  40.300559  1.042939e-06    0.006349
# ME1        -0.734437   6.735093  39.290310  1.277917e-06    0.007780
#
#             p_val_adj
# LDLRAD4      0.000198
# FPR3         0.000268
# RNASE1       0.000434
# MIR181A1HG   0.000454
# ME1          0.000519

# %%
downDEG.shape
# Out:
# (114, 6)

# %%
list(downDEG.index)
# Out:
# ['LDLRAD4',
#  'FPR3',
#  'RNASE1',
#  'MIR181A1HG',
#  'ME1',
#  'TTYH3',
#  'CD36',
#  'LYZ',
#  'GALM',
#  'MPP1',
#  'COTL1',
#  'ACP5',
#  'SDC2',
#  'LMNA',
#  'GSN',
#  'BLVRB',
#  'CAMK1',
#  'TGFBI',
#  'IFI30',
#  'ABHD12',
#  'REV3L',
#  'S100A4',
#  'FBP1',
#  'MARCH1',
#  'VAMP8',
#  'SLCO2B1',
#  'ELMO1',
#  'HEXB',
#  'PLXDC2',
#  'LONRF3',
#  'RCBTB2',
#  'LIPA',
#  'ALDH2',
#  'MGAT1',
#  'ITGA4',
#  'PDK4',
#  'SAMHD1',
#  'PEBP1',
#  'SLC23A2',
#  'RPSA',
#  'CLEC5A',
#  'FOLR2',
#  'VWA8',
#  'MPHOSPH6',
#  'MS4A4A',
#  'GPR34',
#  'UBE2L6',
#  'ZNF385A',
#  'PCBD1',
#  'CTSD',
#  'FOXN3',
#  'FABP5',
#  'IL18',
#  'GDF15',
#  'HLA-DMA',
#  'TMEM170B',
#  'SOGA1',
#  'DPP7',
#  'STAC',
#  'F13A1',
#  'LSM2',
#  'CPVL',
#  'CHD9',
#  'DNASE2',
#  'PPM1L',
#  'ARHGAP10',
#  'KIAA1143',
#  'KIAA0100',
#  'MS4A6A',
#  'LSP1',
#  'C1orf54',
#  'GAS2L3',
#  'LYL1',
#  'SNHG7',
#  'OGFR',
#  'MRC1',
#  'JAKMIP2',
#  'MNDA',
#  'ZFP36L2',
#  'CHCHD10',
#  'DLEU2',
# ...

# %% [raw]
# temp= pd.read_table('../results/SC_Immune_LIS_24h/2_DEGs_DOWN_SC_LIS_24h_PAMM1.tsv', index_col=0)
# list(temp.index)
