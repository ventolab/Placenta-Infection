# %% [markdown]
# **Author:** Elias Rafael Ruiz-Morales
#
# **Institution:** Wellcome Sanger institute
#
# **August, 2022**

# %% [markdown]
# ---

# %% [markdown]
# ### rna1b_All_preprocessing
#
# scRNA-Seq of Placental explants

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import matplotlib
import os
import sys
# %matplotlib inline
import seaborn as sns
import seaborn as sb
from glob import iglob
import anndata
import matplotlib as mpl
import skmisc
import gc

    
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.figdir = '../results/images/preprocessing/'
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

sys.executable


fig_path= '../results/images/preprocessing/'
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.1
# sinfo       0.3.1
# -----
# PIL                 8.1.2
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                3.1.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# numpy               1.20.1
# packaging           20.9
# pandas              1.2.3
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# scanpy              1.7.1
# scipy               1.6.1
# seaborn             0.11.1
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.24.1
# skmisc              0.1.4
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# statsmodels         0.12.2
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.3.1
# zmq                 22.0.3
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-213-generic-x86_64-with-glibc2.10
# 26 logical CPU cores, x86_64
# -----
# Session information updated at 2023-11-27 15:41

# %%
def Barplot(which_var, adata, var='identity', height=3, color = False, suffix= ''):
    
    '''
    Function to plot barplots plotting the proportion of cells per catergory in var, coming from each category in which_var.
    
    Parameters:
        which_var: column name in .obs. Contains the categories to contrast.
        adata: anndata object.
        var: column name in .obs. It contains the categories of the cells.
        height: plot height
        color: colors to use
        suffix: string. Suffix to be added at the end of the name of the plot.
    
    Return:
        Saves bar plot as a pdf.
        
    '''
    
    plotdata = pd.crosstab(adata.obs[var], adata.obs[which_var], normalize='index') * 100
    if 'category' in plotdata.index.dtype.name:
        plotdata.index.reorder_categories(adata.obs[var].cat.categories[::-1])

    if not color:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False)
    else:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False, color = color)
    ax1.set_title(which_var+' %')
    ax1.set_ylabel(var)
    horiz_offset = 1
    vert_offset = 1.
    ax1 = ax1.legend(bbox_to_anchor = (horiz_offset, vert_offset))
    ax1.figure.savefig(str(sc.settings.figdir)+'/barplot_'+var+'_proportions_'+which_var+ suffix+'.pdf', bbox_inches='tight',
                       dpi=300, orientation='landscape', format= 'pdf', optimize=True)

# %% [markdown]
# ### Import data

# %%
adata_Tg = sc.read('../data/rna1_counts_Tg_adata.h5ad')
adata_Lm = sc.read('../data/rna1_counts_Lm_adata.h5ad')
adata_Pf = sc.read('../data/rna1_counts_Pf_adata.h5ad')

# %%
set(adata_Tg.obs["batch"])
# Out:
# {'0', '1', '2', '3'}

# %%
set(adata_Lm.obs["batch"])
# Out:
# {'0', '1', '2', '3'}

# %%
set(adata_Pf.obs["batch"])
# Out:
# {'0', '1', '2', '3'}

# %% [markdown]
# #### Correcting batch numbers for concatenation
# As the batch numbers are repeated between infections, I will modify them. The order will be Lm= 0-7. Pf= 8-19. Tg= 20-27

# %%
#Function that changes the cluster names as indicated

#Function that changes the cluster names as indicated
adata_Pf.obs['batch'] = (adata_Pf.obs["batch"].map(lambda x: 
                            {"0": "4", "1": "5",  "2": "6", "3":"7"}
                            .get(x, x)).astype("category"))

#Function that changes the cluster names as indicated
adata_Tg.obs['batch'] = (adata_Tg.obs["batch"].map(lambda x: 
                            {"0": "8", "1": "9", "2":"10", "3":"11"}
                            .get(x, x)).astype("category"))

# %% [markdown]
# ### Subsetting only the hs genes taken from the Lm object

# %%
#Keeping hs genes only
#adata_Tg= adata_Tg[:, list(adata_Lm.var.index)].copy()

# %%
#The intersection will only be hs genes
hsGenes= list(set(adata_Lm.var.index).intersection(set(adata_Pf.var.index)))

# %%
#Pf data has less genes due to Reginas preprocessing. Keeping only those ones
adata_Lm= adata_Lm[:, hsGenes].copy()
adata_Pf= adata_Pf[:, hsGenes].copy()
adata_Tg= adata_Tg[:, hsGenes].copy()
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
#removing the extra columns in .var corresponding to the Tg preprocessing
adata_Tg.var= adata_Tg.var.drop(columns=['tg','hs','n_cells_by_counts', 'mean_counts','pct_dropout_by_counts','total_counts'])

# %%
gc.collect()
# Out:
# 1730

# %% [markdown]
# ### Concatenate datasets

# %%
adata_Lm.X= adata_Lm.layers['raw_counts'].copy()
adata_Pf.X= adata_Pf.layers['raw_counts'].copy()
adata_Tg.X= adata_Tg.layers['raw_counts'].copy()

# %%
adata = adata_Tg.concatenate(adata_Pf,adata_Lm, index_unique=None)

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
# Out:
# Total number of cells: 162585
# Total number of genes: 36601

# %%
#adata.obs.to_csv('./adataObs.csv')

# %%
del(adata_Lm)
del(adata_Pf)
del(adata_Tg)
gc.collect()
# Out:
# 1070

# %% [markdown]
# # QC plots

# %%
## Deleting the cells expressing less than 10 genes
sc.pp.filter_cells(adata, min_genes=10)
print('Total number of cells: {:d}'.format(adata.n_obs))
# Out:
# Total number of cells: 162585

# %%
sc.set_figure_params(figsize=(20,10))

# %%
#sc.pl.violin(adata, ['n_genes', 'n_counts','percent_mito'], groupby='donor_souporcell', rotation=45, save='_before_qc.pdf') 
sc.pl.violin(adata, ['n_genes', 'n_counts','percent_mito'], groupby='sample', rotation=30, save='_before_qc.pdf', wspace=5, )
# Out:
# ... storing 'sample' as categorical
# ... storing 'stage' as categorical
# ... storing 'donor' as categorical
# ... storing 'infection' as categorical
# ... storing 'sample_barcode' as categorical
# ... storing 'assignment_SoC' as categorical
# ... storing 'donor_id' as categorical
# ... storing 'infection_stage' as categorical
# ... storing 'Tg_infected' as categorical
# WARNING: saving figure to file ../results/images/preprocessing/violin_before_qc.pdf

# %%
sc.set_figure_params(figsize=(6.4,4.8))

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],jitter=0.4, multi_panel=True, save='.pdf')
sc.pl.scatter(adata, x='n_counts', y='percent_mito', save='_numi_vs_mito.pdf')
sc.pl.scatter(adata, x='n_counts', y='n_genes', save='_numi_vs_ngenes.pdf')
# Out:
# WARNING: saving figure to file ../results/images/preprocessing/violin.pdf
# WARNING: saving figure to file ../results/images/preprocessing/scatter_numi_vs_mito.pdf
# WARNING: saving figure to file ../results/images/preprocessing/scatter_numi_vs_ngenes.pdf

# %% [markdown]
# ### Filtering the number of genes

# %%
sc.set_figure_params(figsize=(6.4,4.8))

# %%
plt.hist(adata.obs['n_genes'], bins = 100)
plt.axvline(200, linestyle = '--', color = 'red')
plt.axvline(450, linestyle = '--', color = 'darkred')

# %%
#deleting the cells expressing less than 450 genes
sc.pp.filter_cells(adata, min_genes=450)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
plt.hist(adata.obs['n_genes'], bins = 100)
plt.axvline(400, linestyle = '--', color = 'red')

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
#adata.obs['donor_souporcell'].values.describe()
adata.obs['sample'].values.describe()
# Out:
# Total number of cells: 140485
# Total number of genes: 36601
#                   counts     freqs
# categories
# Pla_HDBR12330714   14360  0.102217
# Pla_HDBR12330715   13713  0.097612
# Pla_HDBR13007976   11348  0.080777
# Pla_HDBR13007977   10214  0.072705
# Pla_HDBR13661567   10691  0.076101
# Pla_HDBR13661568    9231  0.065708
# Pla_HDBR13661573    5185  0.036908
# Pla_HDBR13661574    6760  0.048119
# Pla_HDBR13661575   13642  0.097106
# Pla_HDBR13661576   17100  0.121721
# Pla_HDBR13798225   13817  0.098352
# Pla_HDBR13798226   14424  0.102673

# %% [markdown]
# ### Filter cells by counts

# %%
plt.hist(adata.obs['n_counts'], bins = 100)
plt.axvline(1000, linestyle = '--', color = 'red')
plt.axvline(50000, linestyle = '--', color = 'red')

# %%
sc.pp.filter_cells(adata, min_counts = 1000)
print('Number of cells after min count filter: {:d}'.format(adata.n_obs))

#sc.pp.filter_cells(adata, max_counts = 50000)
#print('Number of cells after max count filter: {:d}'.format(adata.n_obs))
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# Number of cells after min count filter: 137393

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
# Out:
# Total number of cells: 137393
# Total number of genes: 36601

# %% [markdown]
# ### Filter cells with large % mitochondrial genes

# %%
sc.set_figure_params(figsize=(8.5,4.8))

# %%
sc.pl.violin(adata, ['percent_mito'], groupby='sample', rotation=75 ) #

# %%
#Histogram Y number of cells, X mitocondrial percentage
plt.hist(adata.obs['percent_mito'], bins = 100, cumulative=True)
plt.axvline(0.1, linestyle = '--', color = 'red')
plt.axvline(0.2, linestyle = '--', color = 'darkred')
plt.axhline(adata.n_obs*0.99, linestyle = '-', color = 'green')

# %%
# Keeping cells with <10%
adata = adata[adata.obs['percent_mito'] < 0.2, :]
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
adata.obs['donor'].values.describe()
pd.DataFrame(adata.obs).to_csv(str(sc.settings.figdir)+'/metadata_filtered.csv')
# Out:
# Total number of cells: 122827
# Total number of genes: 36601

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 122827 × 36601
#     obs: 'sample', 'stage', 'donor', 'hpi', 'infection', 'percent_mito', 'n_counts', 'batch', 'sample_barcode', 'assignment_SoC', 'donor_id', 'scrublet_score', 'scrublet_cluster_score', 'zscore', 'bh_pval', 'bonf_pval', 'is_doublet', 'infection_stage', 'S_score', 'G2M_score', 'phase', 'n_genes_by_counts', 'total_counts', 'total_counts_hs', 'pct_counts_hs', 'total_counts_tg', 'pct_counts_tg', 'Tg_infected', 'n_genes'
#     var: 'gene_ids', 'feature_types', 'mean-0', 'std-0', 'mean-1', 'std-1', 'mean-2', 'std-2'
#     uns: 'sample_colors'
#     layers: 'raw_counts'

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts','percent_mito'], groupby='sample', rotation=45, save='_afterQC_Sample.pdf')
sc.pl.violin(adata, ['n_genes', 'n_counts','percent_mito'], groupby='donor_id', rotation=45, save='_afterQC_Donor.pdf')
# Out:
# WARNING: saving figure to file ../results/images/preprocessing/violin_afterQC_Sample.pdf
# Trying to set attribute `.uns` of view, copying.
# WARNING: saving figure to file ../results/images/preprocessing/violin_afterQC_Donor.pdf

# %%
sc.pl.violin(adata, ['n_genes', 'n_counts','percent_mito'], groupby='infection', rotation=45, save='_afterQC_Infection.pdf')
# Out:
# WARNING: saving figure to file ../results/images/preprocessing/violin_afterQC_Infection.pdf

# %%
adata.obs['sample'].values.describe()
# Out:
#                   counts     freqs
# categories
# Pla_HDBR12330714   12538  0.102079
# Pla_HDBR12330715   11109  0.090444
# Pla_HDBR13007976   10621  0.086471
# Pla_HDBR13007977    9958  0.081073
# Pla_HDBR13661567    8159  0.066427
# Pla_HDBR13661568    8120  0.066109
# Pla_HDBR13661573    4775  0.038876
# Pla_HDBR13661574    5305  0.043191
# Pla_HDBR13661575   10818  0.088075
# Pla_HDBR13661576   15420  0.125542
# Pla_HDBR13798225   12719  0.103552
# Pla_HDBR13798226   13285  0.108160

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
adata.obs['donor_id'].values.describe()
#adata.obs['donor_souporcell'].values.describe()
# Out:
# Total number of cells: 122827
# Total number of genes: 36601
#                 counts     freqs
# categories
# Hrv135            3681  0.029969
# Hrv136           16597  0.135125
# Hrv232           16279  0.132536
# Hrv236           36318  0.295684
# donor_doublets    8172  0.066533
# scDonor_Tg1       8286  0.067461
# scDonor_Tg2       9369  0.076278
# scDonor_Tg3      10750  0.087521
# scDonor_Tg4      13375  0.108893

# %% [markdown]
# ## Highly variable genes

# %%
#sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
#sc.pp.log1p(adata)

# %%
#  HVGs. Seurat 3 expects non-normalized counts
sc.pp.highly_variable_genes(adata, n_top_genes=3000, flavor='seurat_v3')
sc.pl.highly_variable_genes(adata)


print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# /opt/conda/lib/python3.8/site-packages/scanpy/preprocessing/_highly_variable_genes.py:144: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   df.loc[: int(n_top_genes), 'highly_variable'] = True
# Total number of cells: 122827
# Total number of genes: 36601

# %% [markdown]
# ## Removing Hrv135 as it doesn't have an infected counterpart

# %%
adata = adata[adata.obs['donor_id'] != 'Hrv135']

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 119146 × 36601
#     obs: 'sample', 'stage', 'donor', 'hpi', 'infection', 'percent_mito', 'n_counts', 'batch', 'sample_barcode', 'assignment_SoC', 'donor_id', 'scrublet_score', 'scrublet_cluster_score', 'zscore', 'bh_pval', 'bonf_pval', 'is_doublet', 'infection_stage', 'S_score', 'G2M_score', 'phase', 'n_genes_by_counts', 'total_counts', 'total_counts_hs', 'pct_counts_hs', 'total_counts_tg', 'pct_counts_tg', 'Tg_infected', 'n_genes'
#     var: 'gene_ids', 'feature_types', 'mean-0', 'std-0', 'mean-1', 'std-1', 'mean-2', 'std-2', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'sample_colors', 'donor_id_colors', 'infection_colors', 'hvg'
#     layers: 'raw_counts'

# %% [markdown]
# ### Saving raw counts

# %%
adata.write('../data/rna1_counts_preprocessed_All_adata.h5ad')
#adata=sc.read('../data/S1_preprocessed_noNormalized_adata.h5ad')

# %%
adata.obs
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCACACTAAACC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# ...                                             ...     ...            ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT  Pla_HDBR13661576  Lm_48h         Hrv236
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG  Pla_HDBR13661576  Lm_48h         Hrv236
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT  Pla_HDBR13661576  Lm_48h         Hrv236
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA  Pla_HDBR13661576  Lm_48h         Hrv236
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA  Pla_HDBR13661576  Lm_48h         Hrv236
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
# Pla_HDBR13007976_AAACCCACACTAAACC  48h        UI      0.014511   29081.0
# ...                                ...       ...           ...       ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT  48h        Lm      0.026275   37298.0
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG  48h        Lm      0.044556    6576.0
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT  48h        Lm      0.049094   21082.0
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA  48h        Lm      0.082192    3942.0
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA  48h        Lm      0.135040   13322.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
# Pla_HDBR13007976_AAACCCACACTAAACC     0  Pla_HDBR13007976_AAACCCACACTAAACC
# ...                                 ...                                ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT     2  Pla_HDBR13661576_TTTGTTGGTCACTGAT
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG     2  Pla_HDBR13661576_TTTGTTGGTTTCGGCG
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT     2  Pla_HDBR13661576_TTTGTTGTCAGCTGAT
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA     2  Pla_HDBR13661576_TTTGTTGTCGGTTGTA
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA     2  Pla_HDBR13661576_TTTGTTGTCTGGTTGA
#
#                                   assignment_SoC  ... G2M_score  phase  \
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1  ... -0.026165     G1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0  ... -0.092429     G1
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1  ... -0.057789      S
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0  ... -0.092744     G1
# Pla_HDBR13007976_AAACCCACACTAAACC              1  ...  0.007552    G2M
# ...                                          ...  ...       ...    ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT     not_pooled  ... -0.076960      S
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG     not_pooled  ...  1.025595    G2M
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT     not_pooled  ... -0.028451      S
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA     not_pooled  ...  0.129952    G2M
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA     not_pooled  ... -0.094771     G1
#
#                                    n_genes_by_counts  total_counts  \
# Pla_HDBR13007976_AAACCCAAGCCTCATA             6472.0       32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC             3822.0       33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG             4489.0       17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA              450.0        6358.0
# Pla_HDBR13007976_AAACCCACACTAAACC             4465.0       29081.0
# ...                                              ...           ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT                NaN           NaN
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG                NaN           NaN
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT                NaN           NaN
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA                NaN           NaN
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA                NaN           NaN
#
#                                    total_counts_hs  pct_counts_hs  \
# Pla_HDBR13007976_AAACCCAAGCCTCATA          32751.0          100.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC          33232.0          100.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG          17502.0          100.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA           6358.0          100.0
# Pla_HDBR13007976_AAACCCACACTAAACC          29081.0          100.0
# ...                                            ...            ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT              NaN            NaN
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG              NaN            NaN
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT              NaN            NaN
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA              NaN            NaN
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA              NaN            NaN
#
#                                    total_counts_tg pct_counts_tg  Tg_infected  \
# Pla_HDBR13007976_AAACCCAAGCCTCATA              0.0           0.0        False
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0.0           0.0        False
# Pla_HDBR13007976_AAACCCAAGGCATCAG              0.0           0.0        False
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0.0           0.0        False
# Pla_HDBR13007976_AAACCCACACTAAACC              0.0           0.0        False
# ...                                            ...           ...          ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT              NaN           NaN          nan
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG              NaN           NaN          nan
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT              NaN           NaN          nan
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA              NaN           NaN          nan
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA              NaN           NaN          nan
#
#                                    n_genes
# Pla_HDBR13007976_AAACCCAAGCCTCATA     6472
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     3822
# Pla_HDBR13007976_AAACCCAAGGCATCAG     4489
# Pla_HDBR13007976_AAACCCAAGGGAGATA      450
# Pla_HDBR13007976_AAACCCACACTAAACC     4465
# ...                                    ...
# Pla_HDBR13661576_TTTGTTGGTCACTGAT     7275
# Pla_HDBR13661576_TTTGTTGGTTTCGGCG     3047
# Pla_HDBR13661576_TTTGTTGTCAGCTGAT     5860
# Pla_HDBR13661576_TTTGTTGTCGGTTGTA     1988
# Pla_HDBR13661576_TTTGTTGTCTGGTTGA     4066
#
# [119146 rows x 29 columns]
