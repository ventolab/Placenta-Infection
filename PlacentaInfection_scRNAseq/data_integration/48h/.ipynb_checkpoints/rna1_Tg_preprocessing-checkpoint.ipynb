# %% [markdown]
# **Author:** Elias Rafael Ruiz-Morales
#
# **Institution:** Wellcome Sanger institute
#
# **July, 2023**

# %% [markdown]
# ---

# %% [markdown]
# ##  rna_S1_preprocessing Tg

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import matplotlib
import os
import sys
# %matplotlib inline
import seaborn as sns
import seaborn as sb
from glob import iglob
import anndata
import matplotlib as mpl
import skmisc

    
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.figdir = '../results/images/preprocessing/'
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

sys.executable


fig_path= '../results/images/preprocessing/'
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.1
# sinfo       0.3.1
# -----
# PIL                 8.1.2
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                3.1.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# numpy               1.20.1
# packaging           20.9
# pandas              1.2.3
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# scanpy              1.7.1
# scipy               1.6.1
# seaborn             0.11.1
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.24.1
# skmisc              0.1.4
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# statsmodels         0.12.2
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.3.1
# zmq                 22.0.3
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-213-generic-x86_64-with-glibc2.10
# 26 logical CPU cores, x86_64
# -----
# Session information updated at 2023-11-27 14:19

# %%
def Barplot(which_var, adata, var='identity', height=3, color = False, suffix= ''):
    
    '''
    Function to plot barplots plotting the proportion of cells per catergory in var, coming from each category in which_var.
    
    Parameters:
        which_var: column name in .obs. Contains the categories to contrast.
        adata: anndata object.
        var: column name in .obs. It contains the categories of the cells.
        height: plot height
        color: colors to use
        suffix: string. Suffix to be added at the end of the name of the plot.
    
    Return:
        Saves bar plot as a pdf.
        
    '''
    
    plotdata = pd.crosstab(adata.obs[var], adata.obs[which_var], normalize='index') * 100
    if 'category' in plotdata.index.dtype.name:
        plotdata.index.reorder_categories(adata.obs[var].cat.categories[::-1])

    if not color:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False)
    else:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False, color = color)
    ax1.set_title(which_var+' %')
    ax1.set_ylabel(var)
    horiz_offset = 1
    vert_offset = 1.
    ax1 = ax1.legend(bbox_to_anchor = (horiz_offset, vert_offset))
    ax1.figure.savefig(str(sc.settings.figdir)+'/barplot_'+var+'_proportions_'+which_var+ suffix+'.pdf', bbox_inches='tight',
                       dpi=300, orientation='landscape', format= 'pdf', optimize=True)

# %%
### Function to add the souporcell cluster
####

def add_souporcell_id(adata_obj, cell_id, samples):
    '''
    Function to add the souporcell status (e.g. 0,1, not pooled, etc.) to the cells
    
    Input
        adata_obj: adata object
        cell_id: id of a cell
        samples: list of samples that were pooled. Usually not all samples are multiplexed.
    
    '''
    
    curr_sample = adata_obj.obs.loc[cell_id, 'sample']
    
    #print('sample',sample, 'barcode', cell_id)
    
    if curr_sample in samples:
        #extracts the table contained in the indicated key of the dictionary
        curr_souporcell_table = souporcell_clusters[curr_sample]
        
        if (cell_id in list(curr_souporcell_table.index)): #checking that the cells are into the data
            curr_assign = souporcell_clusters[curr_sample].loc[cell_id,'assignment']
            #print('returning',curr_assign)
            return(curr_assign)

        else:
            # cell barcode is filtered by souporcell
            return('filtered_by_souporcell')
    else:
        return('not_pooled')

# %%
def decode_donors(adata_obj, cell_id, identity_dict,samples):

    '''
    Function to add the true identity to the multiplexed samples. The souporcell samples are changed
    to the real names of the clusters(e.g. 0= Hrv99, 1=Hrv98).
    
    Input
        adata_obj: adata object
        cell_id: id of a cell
        identity_dict: dictionary with the identity of each cluster per each sample. It has the structure sample:{cluster:donor}.
        samples: list of samples to be considered in the function. Not all samples are multiplexed
    '''
    
    
    #sample name
    curr_sample = adata_obj.obs.loc[cell_id, 'sample']
    
    #cluster name
    curr_souporcell_cluster = adata_obj.obs.loc[cell_id, 'assignment_SoC']

    if curr_sample in samples:
        #this means that the cell could not be assigned to a cluster (e.g. 2/3), therefore it is considered as a doublet
        if '/' in curr_souporcell_cluster:
            return('donor_doublets')
        
        #Condition for cells that were filtered by SoC. These will be deleted later.
        elif "filtered" in curr_souporcell_cluster:
            return('filtered_by_souporcell')
        
        #Singlets with a donor assigned
        else:
            return(identity_dict[curr_sample][curr_souporcell_cluster])

# %% [markdown]
# ### Import data

# %%
data_dir ='/lustre/scratch126/cellgen/team292/er13/PlacInfection_revision/scRNAseq/data_integration/48h/data/Toxoplasma/'

meta = pd.read_csv(data_dir+'meta_exp_infection_Tg_scell.csv',index_col=0)
meta['donor'] = meta['donor'].astype('str')
plotmeta = list(meta.columns)
plotmeta.append('sample')
print('Number of samples: ', meta.index.size)
# Out:
# Number of samples:  4

# %%
meta
# Out:
#                    stage          donor  hpi infection
# sample
# Pla_HDBR13007976  UI_48h  Hrv171_Hrv172  48h        UI
# Pla_HDBR13007977  Tg_48h  Hrv171_Hrv172  48h        Tg
# Pla_HDBR13798225  UI_48h  Hrv241_Hrv242  48h        UI
# Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242  48h        Tg

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# No basic filtering at this stage to keep integrate the parasite genes
#
# Quantify: 1) % mitochondrial genes; 2) total counts

# %%
data_dir ='/lustre/scratch126/cellgen/team292/er13/PlacInfection_revision/scRNAseq/data_integration/24h/data/Toxoplasma/'

# %%
holder = []
for sample in meta.index:
    print(sample)
    # Load 10x data as AnnData

    holder.append(sc.read_10x_mtx(data_dir+sample+'/output/GeneFull/filtered/',var_names='gene_symbols',cache=True)) 
    print('Original number of cells: {:d}'.format(holder[-1].n_obs))
    
    holder[-1].var_names_make_unique()
    holder[-1].obs_names = [sample+'_'+i.split('-')[0] for i in holder[-1].obs_names]
    
    
    # Filer cells with less than 100 genes expressed
    #sc.pp.filter_cells(holder[-1], min_genes=100)
    
    #Filer genes expressed in less than 3 cells
    #sc.pp.filter_genes(holder[-1], min_cells=3)
    
    
    # add in metadata
    holder[-1].obs['sample'] = sample
    for val in meta.columns:
        holder[-1].obs[val] = meta[val][sample]
    
    # Extract mitochondial genes
    mito_genes = [name for name in holder[-1].var_names if name.startswith('MT-')]
    #for each cell compute fraction of counts in mito genes vs. all genes
    #the `.A1` is only necessary, as X is sparse - it transform to a dense array after summing
    holder[-1].obs['percent_mito'] = np.sum(
         holder[-1][:, mito_genes].X, axis=1).A1 / np.sum(holder[-1].X, axis=1).A1
    
    #add the total counts per cell as observations-annotation to adata
    holder[-1].obs['n_counts'] = holder[-1].X.sum(axis=1).A1
    
    print('Total number of cells: {:d}'.format(holder[-1].n_obs))
    print('Total number of genes: {:d}'.format(holder[-1].n_vars))
# Out:
# Pla_HDBR13007976
# Original number of cells: 15054
# Total number of cells: 15054
# Total number of genes: 45238
# Pla_HDBR13007977
# Original number of cells: 11352
# Total number of cells: 11352
# Total number of genes: 45238
# Pla_HDBR13798225
# Original number of cells: 16693
# Total number of cells: 16693
# Total number of genes: 45238
# Pla_HDBR13798226
# Original number of cells: 17582
# Total number of cells: 17582
# Total number of genes: 45238

# %%
# confirm N samples
print(len(holder))
# merge datasets by taking the intersection of cells found between cells 
adata = holder[0].concatenate(holder[1:],join='outer',index_unique=None)
# copy of this matrix in Compressed Sparse Row format
adata.X = adata.X.tocsr()
adata
# Out:
# 4
# AnnData object with n_obs × n_vars = 60681 × 45238
#     obs: 'sample', 'stage', 'donor', 'hpi', 'infection', 'percent_mito', 'n_counts', 'batch'
#     var: 'gene_ids', 'feature_types'

# %%
adata.obs.head()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGACATATG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
#
#                                    hpi infection  percent_mito  n_counts batch
# Pla_HDBR13007976_AAACCCAAGACATATG  48h        UI      0.013781    1161.0     0
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0     0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0     0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0     0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0     0

# %% [markdown]
# # Souporcell
# Adding another column with deconvolution from souporcell

# %%
samples = list(np.unique(adata.obs['sample']))

# %%
samples
# Out:
# ['Pla_HDBR13007976',
#  'Pla_HDBR13007977',
#  'Pla_HDBR13798225',
#  'Pla_HDBR13798226']

# %%
###reading in souporcell outputs
###

soc_path='/lustre/scratch126/cellgen/team292/er13/PlacInfection_revision/scRNAseq/data_integration/24h/data/Toxoplasma/souporcell_donor/'

# sample to cluster
souporcell_clusters = {}


for sample in samples:
    print('sample', sample)
    path =soc_path+sample+'/soc2/clusters.tsv' #path to the souporcell output
    souporcell_clusters[sample] = pd.read_csv(path, sep='\t') #read souporcell output as pandas DF
    #aadind the DF into the dictionary
    souporcell_clusters[sample]['sample_barcode'] = [sample+'_'+j for j in souporcell_clusters[sample]['barcode']]
    souporcell_clusters[sample]['sample_barcode'] = [elem.split('-')[0] for elem in souporcell_clusters[sample]['sample_barcode']]
    souporcell_clusters[sample].set_index('sample_barcode', drop=False, inplace=True)
# Out:
# sample Pla_HDBR13007976
# sample Pla_HDBR13007977
# sample Pla_HDBR13798225
# sample Pla_HDBR13798226

# %%
#Adding a column into the metada that is actually the cell ID
adata.obs['sample_barcode'] = adata.obs.index

# %%
# %%time
adata.obs['assignment_SoC'] = adata.obs['sample_barcode'].apply(lambda x: add_souporcell_id(adata,x,samples))
# Out:
# CPU times: user 1min 5s, sys: 0 ns, total: 1min 5s
# Wall time: 1min 5s

# %%
adata.obs
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGACATATG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# ...                                             ...     ...            ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGCACGACAGA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCATCACAG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGACATATG  48h        UI      0.013781    1161.0
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# ...                                ...       ...           ...       ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  48h        Tg      0.001963    7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA  48h        Tg      0.019309    8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  48h        Tg      0.083441   26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG  48h        Tg      0.074070   18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  48h        Tg      0.075354   19614.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGACATATG     0  Pla_HDBR13007976_AAACCCAAGACATATG
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# ...                                 ...                                ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG     3  Pla_HDBR13798226_TTTGTTGCAACTGCCG
# Pla_HDBR13798226_TTTGTTGCACGACAGA     3  Pla_HDBR13798226_TTTGTTGCACGACAGA
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT     3  Pla_HDBR13798226_TTTGTTGGTTGAGTCT
# Pla_HDBR13798226_TTTGTTGTCATCACAG     3  Pla_HDBR13798226_TTTGTTGTCATCACAG
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA     3  Pla_HDBR13798226_TTTGTTGTCTCGTTTA
#
#                                            assignment_SoC
# Pla_HDBR13007976_AAACCCAAGACATATG  filtered_by_souporcell
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                       0
# Pla_HDBR13007976_AAACCCAAGCCTCATA                       1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC                       0
# Pla_HDBR13007976_AAACCCAAGGCATCAG                       1
# ...                                                   ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG                       1
# Pla_HDBR13798226_TTTGTTGCACGACAGA                       1
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT                     1/0
# Pla_HDBR13798226_TTTGTTGTCATCACAG                       1
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA                       1
#
# [60681 rows x 10 columns]

# %% [markdown]
# #### Deconvolution of the donors
# This step must be done even if there are not defined donors, in order to annotate the doublets.
# The deconvolution of cluster equivalents was done using SoC shared_samples.py script. The loss values for true pairs must be low, in some cases, 1/10th that of invalid pairs.

# %%
### Building a dictionary with the identity of the cluster in each one of the samples.
### It has the structure SAMPLE:{Cluster:Donor,Cluster:Donor}

identity_dict={
    "Pla_HDBR13007976":{'0':'0','1':'1'},
    "Pla_HDBR13007977":{'0':'0','1':'1'},
    #to avoid repetition of clusters between multiplexed samples for these samples 0=2, 1=3
    "Pla_HDBR13798225":{'0':'2','1':'3'},
    "Pla_HDBR13798226":{'0':'2','1':'3'}
}

identity_dict
# Out:
# {'Pla_HDBR13007976': {'0': '0', '1': '1'},
#  'Pla_HDBR13007977': {'0': '0', '1': '1'},
#  'Pla_HDBR13798225': {'0': '2', '1': '3'},
#  'Pla_HDBR13798226': {'0': '2', '1': '3'}}

# %%
# %%time
#NOTE: cells that weren't pooled will have None in the donor_deconv column
adata.obs['donor_deconv'] = adata.obs['sample_barcode'].apply(lambda x: decode_donors(adata,x,identity_dict, samples))
# Out:
# CPU times: user 834 ms, sys: 0 ns, total: 834 ms
# Wall time: 833 ms

# %%
adata.obs.head()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGACATATG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGACATATG  48h        UI      0.013781    1161.0
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGACATATG     0  Pla_HDBR13007976_AAACCCAAGACATATG
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
#
#                                            assignment_SoC  \
# Pla_HDBR13007976_AAACCCAAGACATATG  filtered_by_souporcell
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                       0
# Pla_HDBR13007976_AAACCCAAGCCTCATA                       1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC                       0
# Pla_HDBR13007976_AAACCCAAGGCATCAG                       1
#
#                                              donor_deconv
# Pla_HDBR13007976_AAACCCAAGACATATG  filtered_by_souporcell
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                       0
# Pla_HDBR13007976_AAACCCAAGCCTCATA                       1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC                       0
# Pla_HDBR13007976_AAACCCAAGGCATCAG                       1

# %%
plt.title(sample)
sns.countplot(adata[adata.obs['sample'] == sample].obs['assignment_SoC'],
                order=adata[adata.obs['sample'] == sample].obs['assignment_SoC'].value_counts().index).set_title(sample)

plt.savefig(fig_path+'Tg_countplot_souporcell_id.pdf')
plt.xticks(rotation=45)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '0/1'), Text(3, 0, '1/0')])

# %%
def donor_assing(adata_obj, cell_id):
    
    '''
    Function that assings a donor ID to the cells that were pooled and not pooled. It keep the ID stored in donor_deconv for those cells
    pooled, and the cells that weren't pooled will keep the original donor ID before deconvolution donor.
    
    input
        adata_obj: adata object
        cell_id:

    '''
    
    #Donor deconvoluted of the current cell
    curr_donor_deconv = adata_obj.obs.loc[cell_id, 'donor_deconv']
    #Donor of the current cell (before deconvolution)
    curr_donor = adata_obj.obs.loc[cell_id, 'donor']
    
    # donor ID from 'donor_id' column
    
    #If the curr_donor_deconv is None, then the function willl return the donor before deconvolution
    # Otherwise it will return the same donor in the donor_deconv column. Which is the real donor. 
    if curr_donor_deconv == 'None':
        return(curr_donor)
    
    elif curr_donor_deconv == None:
        return(curr_donor)
    
    else:
        return(curr_donor_deconv)

# %%
#applying the donor_assing function to the data. The donor names will be stored in the new column donor_souporcell
adata.obs['donor_souporcell'] = adata.obs['sample_barcode'].apply(lambda x: donor_assing(adata,x))
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
adata.obs
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# ...                                             ...     ...            ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGCACGACAGA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCATCACAG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
# ...                                ...       ...           ...       ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  48h        Tg      0.001963    7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA  48h        Tg      0.019309    8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  48h        Tg      0.083441   26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG  48h        Tg      0.074070   18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  48h        Tg      0.075354   19614.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
# ...                                 ...                                ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG     3  Pla_HDBR13798226_TTTGTTGCAACTGCCG
# Pla_HDBR13798226_TTTGTTGCACGACAGA     3  Pla_HDBR13798226_TTTGTTGCACGACAGA
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT     3  Pla_HDBR13798226_TTTGTTGGTTGAGTCT
# Pla_HDBR13798226_TTTGTTGTCATCACAG     3  Pla_HDBR13798226_TTTGTTGTCATCACAG
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA     3  Pla_HDBR13798226_TTTGTTGTCTCGTTTA
#
#                                   assignment_SoC    donor_deconv  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0               0
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1               1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0               0
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1               1
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0               0
# ...                                          ...             ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG              1               3
# Pla_HDBR13798226_TTTGTTGCACGACAGA              1               3
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT            1/0  donor_doublets
# Pla_HDBR13798226_TTTGTTGTCATCACAG              1               3
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA              1               3
#
#                                   donor_souporcell
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                0
# Pla_HDBR13007976_AAACCCAAGCCTCATA                1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC                0
# Pla_HDBR13007976_AAACCCAAGGCATCAG                1
# Pla_HDBR13007976_AAACCCAAGGGAGATA                0
# ...                                            ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG                3
# Pla_HDBR13798226_TTTGTTGCACGACAGA                3
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT   donor_doublets
# Pla_HDBR13798226_TTTGTTGTCATCACAG                3
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA                3
#
# [59012 rows x 12 columns]

# %%
#Deleting the cells filtered by soc
adata= adata[adata.obs['assignment_SoC'] != 'filtered_by_souporcell']
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
adata.obs.head()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
#
#                                   assignment_SoC donor_deconv donor_souporcell
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0            0                0
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1            1                1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0            0                0
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1            1                1
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0            0                0

# %% [markdown]
# #### Assigning donor id to cluster
# I had deconvoluted and matched the 2 different donors in my data set, however I don't really know what cluster is each one of the donors.
#
# I cannot know which donor is each cluster therefore an ID will assign to each donor.
#
# **Donors**: Hrv171, Hrv172, Hrv241 and Hrv242
#
# **ID**: scDonor_Tg1, scDonor_Tg2, scDonor_Tg3, scDonor_Tg4

# %%
set(list(adata.obs.donor_souporcell))
# Out:
# {'0', '1', '2', '3', 'donor_doublets'}

# %%
#Function that changes the cluster names as indicated
adata.obs['donor_id'] = (adata.obs["donor_souporcell"].map(lambda x: 
                            {"0": "scDonor_Tg1", "1": "scDonor_Tg2",
                             "2": "scDonor_Tg3", "3": "scDonor_Tg4",
                             "souporcell_doublet":"donor_doublets" }
                            .get(x, x)).astype("category"))
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
set(list(adata.obs.donor_id))
# Out:
# {'donor_doublets', 'scDonor_Tg1', 'scDonor_Tg2', 'scDonor_Tg3', 'scDonor_Tg4'}

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
# Out:
# Total number of cells: 59012

# %%
adata.obs= adata.obs.drop(columns=['donor_deconv','donor_souporcell'])

# %%
adata.obs
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# ...                                             ...     ...            ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGCACGACAGA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCATCACAG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
# ...                                ...       ...           ...       ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  48h        Tg      0.001963    7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA  48h        Tg      0.019309    8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  48h        Tg      0.083441   26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG  48h        Tg      0.074070   18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  48h        Tg      0.075354   19614.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
# ...                                 ...                                ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG     3  Pla_HDBR13798226_TTTGTTGCAACTGCCG
# Pla_HDBR13798226_TTTGTTGCACGACAGA     3  Pla_HDBR13798226_TTTGTTGCACGACAGA
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT     3  Pla_HDBR13798226_TTTGTTGGTTGAGTCT
# Pla_HDBR13798226_TTTGTTGTCATCACAG     3  Pla_HDBR13798226_TTTGTTGTCATCACAG
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA     3  Pla_HDBR13798226_TTTGTTGTCTCGTTTA
#
#                                   assignment_SoC        donor_id
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0     scDonor_Tg1
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1     scDonor_Tg2
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0     scDonor_Tg1
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1     scDonor_Tg2
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0     scDonor_Tg1
# ...                                          ...             ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG              1     scDonor_Tg4
# Pla_HDBR13798226_TTTGTTGCACGACAGA              1     scDonor_Tg4
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT            1/0  donor_doublets
# Pla_HDBR13798226_TTTGTTGTCATCACAG              1     scDonor_Tg4
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA              1     scDonor_Tg4
#
# [59012 rows x 11 columns]

# %%
data_dir
# Out:
# '/lustre/scratch126/cellgen/team292/er13/PlacInfection_revision/scRNAseq/data_integration/24h/data/Toxoplasma/'

# %% [markdown]
# # Scrublet

# %%
scorenames = ['scrublet_score','scrublet_cluster_score','zscore','bh_pval','bonf_pval']

scrdf = []
for sample in meta.index:
    #reading the scrublet scores done in S0
    scrdf.append(pd.read_csv(data_dir+'scrublet-scores/'+sample+'.csv', header=0, index_col=0))
#scrdf.append(pd.read_csv('scrublet-scores/'+sample+'.csv', header=0, index_col=0))
#scrdf.append(pd.read_csv('scrublet-scores/'+sample+'soupX.csv', header=0, index_col=0))
scrdf = pd.concat(scrdf)
scrdf.index = [i.replace('-1', '') for i in scrdf.index]
for score in scorenames:
    adata.obs[score] = scrdf[score]
# In scrublet the significant p-value mark doublets
adata.obs['is_doublet'] = adata.obs['bonf_pval'] < 0.01

# %%
print('Total number of doublets: {:d}'.format(len(adata.obs.loc[adata.obs['is_doublet'] == True])))
# Out:
# Total number of doublets: 1073

# %%
adata.obs.head()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
#
#                                   assignment_SoC     donor_id  scrublet_score  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0  scDonor_Tg1        0.024707
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1  scDonor_Tg2        0.083395
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0  scDonor_Tg1        0.092913
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1  scDonor_Tg2        0.081633
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0  scDonor_Tg1        0.040869
#
#                                    scrublet_cluster_score    zscore   bh_pval  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                0.031352 -1.200346  0.945880
# Pla_HDBR13007976_AAACCCAAGCCTCATA                0.085202  0.335500  0.896768
# Pla_HDBR13007976_AAACCCAAGCTGTTAC                0.097087  0.674491  0.896768
# Pla_HDBR13007976_AAACCCAAGGCATCAG                0.085202  0.335500  0.896768
# Pla_HDBR13007976_AAACCCAAGGGAGATA                0.015898 -1.641133  0.957485
#
#                                    bonf_pval  is_doublet
# Pla_HDBR13007976_AAACCCAAGAGAGGTA        1.0       False
# Pla_HDBR13007976_AAACCCAAGCCTCATA        1.0       False
# Pla_HDBR13007976_AAACCCAAGCTGTTAC        1.0       False
# Pla_HDBR13007976_AAACCCAAGGCATCAG        1.0       False
# Pla_HDBR13007976_AAACCCAAGGGAGATA        1.0       False

# %%
#concatenating columns and creating new one
adata.obs["infection_stage"] = adata.obs["infection"].astype('string') +'_'+ adata.obs["hpi"]

# %%
adata.obs["infection_stage"] = adata.obs["infection_stage"].astype("category")

# %%
set(adata.obs["infection_stage"])
# Out:
# {'Tg_48h', 'UI_48h'}

# %%
adata.obs
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# ...                                             ...     ...            ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGCACGACAGA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCATCACAG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
# ...                                ...       ...           ...       ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  48h        Tg      0.001963    7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA  48h        Tg      0.019309    8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  48h        Tg      0.083441   26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG  48h        Tg      0.074070   18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  48h        Tg      0.075354   19614.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
# ...                                 ...                                ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG     3  Pla_HDBR13798226_TTTGTTGCAACTGCCG
# Pla_HDBR13798226_TTTGTTGCACGACAGA     3  Pla_HDBR13798226_TTTGTTGCACGACAGA
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT     3  Pla_HDBR13798226_TTTGTTGGTTGAGTCT
# Pla_HDBR13798226_TTTGTTGTCATCACAG     3  Pla_HDBR13798226_TTTGTTGTCATCACAG
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA     3  Pla_HDBR13798226_TTTGTTGTCTCGTTTA
#
#                                   assignment_SoC        donor_id  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0     scDonor_Tg1
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1     scDonor_Tg2
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0     scDonor_Tg1
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1     scDonor_Tg2
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0     scDonor_Tg1
# ...                                          ...             ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG              1     scDonor_Tg4
# Pla_HDBR13798226_TTTGTTGCACGACAGA              1     scDonor_Tg4
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT            1/0  donor_doublets
# Pla_HDBR13798226_TTTGTTGTCATCACAG              1     scDonor_Tg4
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA              1     scDonor_Tg4
#
#                                    scrublet_score  scrublet_cluster_score  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA        0.024707                0.031352
# Pla_HDBR13007976_AAACCCAAGCCTCATA        0.083395                0.085202
# Pla_HDBR13007976_AAACCCAAGCTGTTAC        0.092913                0.097087
# Pla_HDBR13007976_AAACCCAAGGCATCAG        0.081633                0.085202
# Pla_HDBR13007976_AAACCCAAGGGAGATA        0.040869                0.015898
# ...                                           ...                     ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG        0.049718                0.088133
# Pla_HDBR13798226_TTTGTTGCACGACAGA        0.119730                0.112369
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT        0.071253                0.207547
# Pla_HDBR13798226_TTTGTTGTCATCACAG        0.107789                0.103448
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA        0.074028                0.078419
#
#                                      zscore   bh_pval  bonf_pval  is_doublet  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA -1.200346  0.945880        1.0       False
# Pla_HDBR13007976_AAACCCAAGCCTCATA  0.335500  0.896768        1.0       False
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  0.674491  0.896768        1.0       False
# Pla_HDBR13007976_AAACCCAAGGCATCAG  0.335500  0.896768        1.0       False
# Pla_HDBR13007976_AAACCCAAGGGAGATA -1.641133  0.957485        1.0       False
# ...                                     ...       ...        ...         ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  0.118875  0.892993        1.0       False
# Pla_HDBR13798226_TTTGTTGCACGACAGA  0.803940  0.892993        1.0       False
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  3.494365  0.009267        1.0       False
# Pla_HDBR13798226_TTTGTTGTCATCACAG  0.551787  0.892993        1.0       False
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA -0.155729  0.892993        1.0       False
#
#                                   infection_stage
# Pla_HDBR13007976_AAACCCAAGAGAGGTA          UI_48h
# Pla_HDBR13007976_AAACCCAAGCCTCATA          UI_48h
# Pla_HDBR13007976_AAACCCAAGCTGTTAC          UI_48h
# Pla_HDBR13007976_AAACCCAAGGCATCAG          UI_48h
# Pla_HDBR13007976_AAACCCAAGGGAGATA          UI_48h
# ...                                           ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG          Tg_48h
# Pla_HDBR13798226_TTTGTTGCACGACAGA          Tg_48h
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT          Tg_48h
# Pla_HDBR13798226_TTTGTTGTCATCACAG          Tg_48h
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA          Tg_48h
#
# [59012 rows x 18 columns]

# %%
# adding the raw counts
adata.layers['raw_counts']=adata.X

# %% [markdown]
# ## Calculate cell-cycle scores AND (optional)regress out cell cycle genes
#
# We here perform cell cycle scoring. To score a gene list, the algorithm calculates the difference of mean expression of the given list and the mean expression of reference genes. To build the reference, the function randomly chooses a bunch of genes matching the distribution of the expression of the given list. Cell cycle scoring adds three slots in data, a score for S phase, a score for G2M phase and the predicted cell cycle phase.
#
# First read the file with cell cycle genes, from Regev lab and split into S and G2M phase genes. Cell cycle genes were retrieved from the scanpy_usage github site via web browser at RegevLab Github repo.

# %%
#Normalizing the data and scaling for the cell-cycle scoring
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)


# Scale
sc.pp.scale(adata, max_value=10)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
# calculate cell cycle scores

cell_cycle_genes = [x.strip() for x in open('../../24h/data/regev_lab_cell_cycle_genes.txt')]
s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
s_genes = [x for x in s_genes if x in adata.var_names]
g2m_genes = [x for x in g2m_genes if x in adata.var_names]
sc.tl.score_genes_cell_cycle(adata, s_genes=s_genes, g2m_genes=g2m_genes)
# sc.pp.regress_out(adata, ['S_score', 'G2M_score']
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
adata.obs
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# ...                                             ...     ...            ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGCACGACAGA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCATCACAG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
# ...                                ...       ...           ...       ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  48h        Tg      0.001963    7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA  48h        Tg      0.019309    8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  48h        Tg      0.083441   26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG  48h        Tg      0.074070   18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  48h        Tg      0.075354   19614.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
# ...                                 ...                                ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG     3  Pla_HDBR13798226_TTTGTTGCAACTGCCG
# Pla_HDBR13798226_TTTGTTGCACGACAGA     3  Pla_HDBR13798226_TTTGTTGCACGACAGA
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT     3  Pla_HDBR13798226_TTTGTTGGTTGAGTCT
# Pla_HDBR13798226_TTTGTTGTCATCACAG     3  Pla_HDBR13798226_TTTGTTGTCATCACAG
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA     3  Pla_HDBR13798226_TTTGTTGTCTCGTTTA
#
#                                   assignment_SoC  ... scrublet_score  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0  ...       0.024707
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1  ...       0.083395
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0  ...       0.092913
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1  ...       0.081633
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0  ...       0.040869
# ...                                          ...  ...            ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG              1  ...       0.049718
# Pla_HDBR13798226_TTTGTTGCACGACAGA              1  ...       0.119730
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT            1/0  ...       0.071253
# Pla_HDBR13798226_TTTGTTGTCATCACAG              1  ...       0.107789
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA              1  ...       0.074028
#
#                                    scrublet_cluster_score    zscore   bh_pval  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                0.031352 -1.200346  0.945880
# Pla_HDBR13007976_AAACCCAAGCCTCATA                0.085202  0.335500  0.896768
# Pla_HDBR13007976_AAACCCAAGCTGTTAC                0.097087  0.674491  0.896768
# Pla_HDBR13007976_AAACCCAAGGCATCAG                0.085202  0.335500  0.896768
# Pla_HDBR13007976_AAACCCAAGGGAGATA                0.015898 -1.641133  0.957485
# ...                                                   ...       ...       ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG                0.088133  0.118875  0.892993
# Pla_HDBR13798226_TTTGTTGCACGACAGA                0.112369  0.803940  0.892993
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT                0.207547  3.494365  0.009267
# Pla_HDBR13798226_TTTGTTGTCATCACAG                0.103448  0.551787  0.892993
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA                0.078419 -0.155729  0.892993
#
#                                    bonf_pval  is_doublet  infection_stage  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGCCTCATA        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGCTGTTAC        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGGCATCAG        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGGGAGATA        1.0       False           UI_48h
# ...                                      ...         ...              ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGCACGACAGA        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGTCATCACAG        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA        1.0       False           Tg_48h
#
#                                     S_score  G2M_score  phase
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  0.076314   0.081854    G2M
# Pla_HDBR13007976_AAACCCAAGCCTCATA -0.075011  -0.026165     G1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC -0.275247  -0.092429     G1
# Pla_HDBR13007976_AAACCCAAGGCATCAG  0.095535  -0.057789      S
# Pla_HDBR13007976_AAACCCAAGGGAGATA -0.111749  -0.092744     G1
# ...                                     ...        ...    ...
# Pla_HDBR13798226_TTTGTTGCAACTGCCG -0.174780  -0.082264     G1
# Pla_HDBR13798226_TTTGTTGCACGACAGA  0.049415  -0.217707      S
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT -0.041911  -0.091130     G1
# Pla_HDBR13798226_TTTGTTGTCATCACAG  0.116674   0.076019      S
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA -0.224656  -0.102978     G1
#
# [59012 rows x 21 columns]

# %% [markdown]
# ## Save raw counts

# %%
# adding the raw counts
adata.X=adata.layers['raw_counts'].copy()
#adata.raw = adata.copy
adata.write('../data/rna1_counts_Tg_adata.h5ad')
# Out:
# ... storing 'sample' as categorical
# ... storing 'stage' as categorical
# ... storing 'donor' as categorical
# ... storing 'hpi' as categorical
# ... storing 'infection' as categorical
# ... storing 'assignment_SoC' as categorical
# ... storing 'phase' as categorical
# ... storing 'feature_types' as categorical

# %%
#adata=sc.read('../data/rna1_counts_Tg_adata.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 66451 × 45238
#     obs: 'sample', 'stage', 'donor', 'hpi', 'infection', 'percent_mito', 'n_counts', 'batch', 'sample_barcode', 'assignment_SoC', 'donor_id', 'scrublet_score', 'scrublet_cluster_score', 'zscore', 'bh_pval', 'bonf_pval', 'is_doublet', 'infection_stage', 'S_score', 'G2M_score', 'phase'
#     var: 'gene_ids', 'feature_types', 'mean', 'std'
#     uns: 'log1p'
#     layers: 'raw_counts'

# %% [markdown]
# ## Preview of Toxoplasma gondii UMIs

# %% [markdown]
# Looking at the human and Tg genes.
#
# All the Tg genes have the preffix "TGGT1"

# %%
adata.var.head()
# Out:
#                     gene_ids    feature_types      mean       std
# MIR1302-2HG  ENSG00000243485  Gene Expression  0.000142  0.011268
# FAM138A      ENSG00000237613  Gene Expression  0.000000  1.000000
# OR4F5        ENSG00000186092  Gene Expression  0.000039  0.008139
# AL627309.1   ENSG00000238009  Gene Expression  0.009390  0.078329
# AL627309.3   ENSG00000239945  Gene Expression  0.000000  1.000000

# %%
adata.var.tail()
# Out:
#                   gene_ids    feature_types  mean  std
# TGGT1_412230  TGGT1_412230  Gene Expression   0.0  1.0
# TGGT1_412240  TGGT1_412240  Gene Expression   0.0  1.0
# TGGT1_412250  TGGT1_412250  Gene Expression   0.0  1.0
# TGGT1_412260  TGGT1_412260  Gene Expression   0.0  1.0
# TGGT1_300641  TGGT1_300641  Gene Expression   0.0  1.0

# %%
## Selecting the names of the Tg genes only
tg= adata.var.index.str.contains('TGGT1')
print(sum(tg))
# Out:
# 8637

# %%
adata.obs.head()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
#
#                                   assignment_SoC  ... scrublet_score  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0  ...       0.024707
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1  ...       0.083395
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0  ...       0.092913
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1  ...       0.081633
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0  ...       0.040869
#
#                                    scrublet_cluster_score    zscore   bh_pval  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                0.031352 -1.200346  0.945880
# Pla_HDBR13007976_AAACCCAAGCCTCATA                0.085202  0.335500  0.896768
# Pla_HDBR13007976_AAACCCAAGCTGTTAC                0.097087  0.674491  0.896768
# Pla_HDBR13007976_AAACCCAAGGCATCAG                0.085202  0.335500  0.896768
# Pla_HDBR13007976_AAACCCAAGGGAGATA                0.015898 -1.641133  0.957485
#
#                                    bonf_pval  is_doublet  infection_stage  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGCCTCATA        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGCTGTTAC        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGGCATCAG        1.0       False           UI_48h
# Pla_HDBR13007976_AAACCCAAGGGAGATA        1.0       False           UI_48h
#
#                                     S_score  G2M_score  phase
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  0.076314   0.081854    G2M
# Pla_HDBR13007976_AAACCCAAGCCTCATA -0.075011  -0.026165     G1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC -0.275247  -0.092429     G1
# Pla_HDBR13007976_AAACCCAAGGCATCAG  0.095535  -0.057789      S
# Pla_HDBR13007976_AAACCCAAGGGAGATA -0.111749  -0.092744     G1
#
# [5 rows x 21 columns]

# %%
adata.obs.tail()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGCACGACAGA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCATCACAG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  48h        Tg      0.001963    7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA  48h        Tg      0.019309    8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  48h        Tg      0.083441   26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG  48h        Tg      0.074070   18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  48h        Tg      0.075354   19614.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG     3  Pla_HDBR13798226_TTTGTTGCAACTGCCG
# Pla_HDBR13798226_TTTGTTGCACGACAGA     3  Pla_HDBR13798226_TTTGTTGCACGACAGA
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT     3  Pla_HDBR13798226_TTTGTTGGTTGAGTCT
# Pla_HDBR13798226_TTTGTTGTCATCACAG     3  Pla_HDBR13798226_TTTGTTGTCATCACAG
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA     3  Pla_HDBR13798226_TTTGTTGTCTCGTTTA
#
#                                   assignment_SoC  ... scrublet_score  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG              1  ...       0.049718
# Pla_HDBR13798226_TTTGTTGCACGACAGA              1  ...       0.119730
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT            1/0  ...       0.071253
# Pla_HDBR13798226_TTTGTTGTCATCACAG              1  ...       0.107789
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA              1  ...       0.074028
#
#                                    scrublet_cluster_score    zscore   bh_pval  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG                0.088133  0.118875  0.892993
# Pla_HDBR13798226_TTTGTTGCACGACAGA                0.112369  0.803940  0.892993
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT                0.207547  3.494365  0.009267
# Pla_HDBR13798226_TTTGTTGTCATCACAG                0.103448  0.551787  0.892993
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA                0.078419 -0.155729  0.892993
#
#                                    bonf_pval  is_doublet  infection_stage  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGCACGACAGA        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGTCATCACAG        1.0       False           Tg_48h
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA        1.0       False           Tg_48h
#
#                                     S_score  G2M_score  phase
# Pla_HDBR13798226_TTTGTTGCAACTGCCG -0.174780  -0.082264     G1
# Pla_HDBR13798226_TTTGTTGCACGACAGA  0.049415  -0.217707      S
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT -0.041911  -0.091130     G1
# Pla_HDBR13798226_TTTGTTGTCATCACAG  0.116674   0.076019      S
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA -0.224656  -0.102978     G1
#
# [5 rows x 21 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 59012 × 45238
#     obs: 'sample', 'stage', 'donor', 'hpi', 'infection', 'percent_mito', 'n_counts', 'batch', 'sample_barcode', 'assignment_SoC', 'donor_id', 'scrublet_score', 'scrublet_cluster_score', 'zscore', 'bh_pval', 'bonf_pval', 'is_doublet', 'infection_stage', 'S_score', 'G2M_score', 'phase'
#     var: 'gene_ids', 'feature_types', 'mean', 'std'
#     uns: 'log1p'
#     layers: 'raw_counts'

# %%
## --- To be run once the deconvolution is completed

Barplot('donor_id', adata, var= 'infection')
# Out:
# <ipython-input-2-b5d44fa15e4e>:32: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error two minor releases later
#   ax1.figure.savefig(str(sc.settings.figdir)+'/barplot_'+var+'_proportions_'+which_var+ suffix+'.pdf', bbox_inches='tight',

# %% [markdown]
# #### Giving a flag to differentiate human and Tg genes in my data set. Preview of counts

# %%
## Giving a flag to differentiate human and Tg genes in my data set
##
adata.var['hs'] = adata.var.gene_ids.str.startswith('ENSG') ## all human genes
adata.var['tg'] = adata.var.gene_ids.str.startswith('TGGT1') ## all toxoplasma genes


## Calculating the metrics per cell in my data.
sc.pp.calculate_qc_metrics(adata, qc_vars=['hs'], percent_top=None, log1p=False, inplace=True)
sc.pp.calculate_qc_metrics(adata, qc_vars=['tg'], percent_top=None, log1p=False, inplace=True)

# %%
## Look at the hs and tg columns
adata.var
# Out:
#                      gene_ids    feature_types      mean       std     hs  \
# MIR1302-2HG   ENSG00000243485  Gene Expression  0.000142  0.011268   True
# FAM138A       ENSG00000237613  Gene Expression  0.000000  1.000000   True
# OR4F5         ENSG00000186092  Gene Expression  0.000039  0.008139   True
# AL627309.1    ENSG00000238009  Gene Expression  0.009390  0.078329   True
# AL627309.3    ENSG00000239945  Gene Expression  0.000000  1.000000   True
# ...                       ...              ...       ...       ...    ...
# TGGT1_412230     TGGT1_412230  Gene Expression  0.000000  1.000000  False
# TGGT1_412240     TGGT1_412240  Gene Expression  0.000000  1.000000  False
# TGGT1_412250     TGGT1_412250  Gene Expression  0.000000  1.000000  False
# TGGT1_412260     TGGT1_412260  Gene Expression  0.000000  1.000000  False
# TGGT1_300641     TGGT1_300641  Gene Expression  0.000000  1.000000  False
#
#                  tg  n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# MIR1302-2HG   False                 17     0.000288              99.971192
# FAM138A       False                  0     0.000000             100.000000
# OR4F5         False                  2     0.000034              99.996611
# AL627309.1    False               1192     0.021707              97.980072
# AL627309.3    False                  0     0.000000             100.000000
# ...             ...                ...          ...                    ...
# TGGT1_412230   True                  0     0.000000             100.000000
# TGGT1_412240   True                  0     0.000000             100.000000
# TGGT1_412250   True                  0     0.000000             100.000000
# TGGT1_412260   True                  0     0.000000             100.000000
# TGGT1_300641   True                  0     0.000000             100.000000
#
#               total_counts
# MIR1302-2HG           17.0
# FAM138A                0.0
# OR4F5                  2.0
# AL627309.1          1281.0
# AL627309.3             0.0
# ...                    ...
# TGGT1_412230           0.0
# TGGT1_412240           0.0
# TGGT1_412250           0.0
# TGGT1_412260           0.0
# TGGT1_300641           0.0
#
# [45238 rows x 10 columns]

# %%
## Look at the total_counts_hs and total_counts_tg columns
##
adata.obs.head()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCCTCATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGCATCAG  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
# Pla_HDBR13007976_AAACCCAAGGGAGATA  Pla_HDBR13007976  UI_48h  Hrv171_Hrv172
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  48h        UI      0.591171    1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA  48h        UI      0.035724   32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC  48h        UI      0.023832   33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG  48h        UI      0.017998   17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA  48h        UI      0.142183    6358.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA     0  Pla_HDBR13007976_AAACCCAAGAGAGGTA
# Pla_HDBR13007976_AAACCCAAGCCTCATA     0  Pla_HDBR13007976_AAACCCAAGCCTCATA
# Pla_HDBR13007976_AAACCCAAGCTGTTAC     0  Pla_HDBR13007976_AAACCCAAGCTGTTAC
# Pla_HDBR13007976_AAACCCAAGGCATCAG     0  Pla_HDBR13007976_AAACCCAAGGCATCAG
# Pla_HDBR13007976_AAACCCAAGGGAGATA     0  Pla_HDBR13007976_AAACCCAAGGGAGATA
#
#                                   assignment_SoC  ... infection_stage  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0  ...          UI_48h
# Pla_HDBR13007976_AAACCCAAGCCTCATA              1  ...          UI_48h
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0  ...          UI_48h
# Pla_HDBR13007976_AAACCCAAGGCATCAG              1  ...          UI_48h
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0  ...          UI_48h
#
#                                     S_score  G2M_score  phase  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA  0.076314   0.081854    G2M
# Pla_HDBR13007976_AAACCCAAGCCTCATA -0.075011  -0.026165     G1
# Pla_HDBR13007976_AAACCCAAGCTGTTAC -0.275247  -0.092429     G1
# Pla_HDBR13007976_AAACCCAAGGCATCAG  0.095535  -0.057789      S
# Pla_HDBR13007976_AAACCCAAGGGAGATA -0.111749  -0.092744     G1
#
#                                    n_genes_by_counts  total_counts  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA                313        1042.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA               6472       32751.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC               3822       33232.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG               4489       17502.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA                450        6358.0
#
#                                    total_counts_hs pct_counts_hs  \
# Pla_HDBR13007976_AAACCCAAGAGAGGTA           1042.0         100.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA          32751.0         100.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC          33232.0         100.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG          17502.0         100.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA           6358.0         100.0
#
#                                    total_counts_tg  pct_counts_tg
# Pla_HDBR13007976_AAACCCAAGAGAGGTA              0.0            0.0
# Pla_HDBR13007976_AAACCCAAGCCTCATA              0.0            0.0
# Pla_HDBR13007976_AAACCCAAGCTGTTAC              0.0            0.0
# Pla_HDBR13007976_AAACCCAAGGCATCAG              0.0            0.0
# Pla_HDBR13007976_AAACCCAAGGGAGATA              0.0            0.0
#
# [5 rows x 27 columns]

# %%
## Look at the total_counts_hs and total_counts_tg columns
##
adata.obs.tail()
# Out:
#                                              sample   stage          donor  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGCACGACAGA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCATCACAG  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  Pla_HDBR13798226  Tg_48h  Hrv241_Hrv242
#
#                                    hpi infection  percent_mito  n_counts  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG  48h        Tg      0.001963    7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA  48h        Tg      0.019309    8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT  48h        Tg      0.083441   26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG  48h        Tg      0.074070   18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA  48h        Tg      0.075354   19614.0
#
#                                   batch                     sample_barcode  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG     3  Pla_HDBR13798226_TTTGTTGCAACTGCCG
# Pla_HDBR13798226_TTTGTTGCACGACAGA     3  Pla_HDBR13798226_TTTGTTGCACGACAGA
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT     3  Pla_HDBR13798226_TTTGTTGGTTGAGTCT
# Pla_HDBR13798226_TTTGTTGTCATCACAG     3  Pla_HDBR13798226_TTTGTTGTCATCACAG
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA     3  Pla_HDBR13798226_TTTGTTGTCTCGTTTA
#
#                                   assignment_SoC  ... infection_stage  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG              1  ...          Tg_48h
# Pla_HDBR13798226_TTTGTTGCACGACAGA              1  ...          Tg_48h
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT            1/0  ...          Tg_48h
# Pla_HDBR13798226_TTTGTTGTCATCACAG              1  ...          Tg_48h
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA              1  ...          Tg_48h
#
#                                     S_score  G2M_score  phase  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG -0.174780  -0.082264     G1
# Pla_HDBR13798226_TTTGTTGCACGACAGA  0.049415  -0.217707      S
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT -0.041911  -0.091130     G1
# Pla_HDBR13798226_TTTGTTGTCATCACAG  0.116674   0.076019      S
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA -0.224656  -0.102978     G1
#
#                                    n_genes_by_counts  total_counts  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG               1279        7133.0
# Pla_HDBR13798226_TTTGTTGCACGACAGA               2506        8856.0
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT               6055       26378.0
# Pla_HDBR13798226_TTTGTTGTCATCACAG               3957       18172.0
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA               5273       19614.0
#
#                                    total_counts_hs pct_counts_hs  \
# Pla_HDBR13798226_TTTGTTGCAACTGCCG           7133.0    100.000000
# Pla_HDBR13798226_TTTGTTGCACGACAGA           8856.0    100.000000
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT          26266.0     99.575409
# Pla_HDBR13798226_TTTGTTGTCATCACAG          18172.0    100.000000
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA          19614.0    100.000000
#
#                                    total_counts_tg  pct_counts_tg
# Pla_HDBR13798226_TTTGTTGCAACTGCCG              0.0       0.000000
# Pla_HDBR13798226_TTTGTTGCACGACAGA              0.0       0.000000
# Pla_HDBR13798226_TTTGTTGGTTGAGTCT            112.0       0.424596
# Pla_HDBR13798226_TTTGTTGTCATCACAG              0.0       0.000000
# Pla_HDBR13798226_TTTGTTGTCTCGTTTA              0.0       0.000000
#
# [5 rows x 27 columns]

# %%
sc.pl.scatter(adata, x='total_counts_tg', y='total_counts_hs',  color="infection",size=50, save='_HsTgCounts.pdf')
sc.pl.scatter(adata, x='pct_counts_tg', y='total_counts', color="infection", size=30, save='_TotalvsTg.pdf')
sc.pl.scatter(adata, x='pct_counts_hs', y='total_counts', color="infection", size=30, save='_TotalvsHs.pdf')
# Out:
# WARNING: saving figure to file ../results/images/preprocessing/scatter_HsTgCounts.pdf
# WARNING: saving figure to file ../results/images/preprocessing/scatter_TotalvsTg.pdf
# WARNING: saving figure to file ../results/images/preprocessing/scatter_TotalvsHs.pdf

# %%
sc.pl.scatter(adata, x='pct_counts_tg', y='total_counts_hs', color="infection", size=30, save='_TgvsHs.pdf')
# Out:
# WARNING: saving figure to file ../results/images/preprocessing/scatter_TgvsHs.pdf

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
# Out:
# Total number of cells: 59012

# %%
adata.obs['sample'].values.describe()
# Out:
#                   counts     freqs
# categories
# Pla_HDBR13007976   14865  0.251898
# Pla_HDBR13007977   10907  0.184827
# Pla_HDBR13798225   16216  0.274792
# Pla_HDBR13798226   17024  0.288484

# %% [markdown]
# #### Checking if uninfected cells have random (or not) counts from *T. gondii*

# %%
# percentage in a droplet has mostly human genes
#cells with more than 10% of Tg counts
sum(adata.obs.pct_counts_tg > 10)
# Out:
# 337

# %%
## Uninfected:
# cells with more than 0% of Tg counts

nCells_infectedSamples=adata[adata.obs['infection'] == 'UI'].n_obs
print('Total cells from Uninfected explants: {:d}'.format(nCells_infectedSamples))

adata_temp= adata[adata.obs['infection'] == 'UI']
print('Cells with Tg counts >0%: {:d}'.format(sum(adata_temp.obs.pct_counts_tg > 0)))
print('Cells with Tg counts >0.07%: {:d}'.format(sum(adata_temp.obs.pct_counts_tg > 0.07)))
print('Cells with Tg counts >1%: {:d}'.format(sum(adata_temp.obs.pct_counts_tg > 1)))
# Out:
# Total cells from Uninfected explants: 31081
# Cells with Tg counts >0%: 110
# Cells with Tg counts >0.07%: 1
# Cells with Tg counts >1%: 0
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %% [markdown]
# There are 108 with >0% of Tg counts. However, none of the cells have >0.07% of Tg counts. I will set this value as the value of Tg counts expected by chance, this will be my threshold to decide which cells are infected or not

# %%
## Infected explants
#cells with more than 0% of Tg counts

nCells_infectedSamples=adata[adata.obs['infection'] == 'Tg'].n_obs
print('Total cells from infected explants: {:d}'.format(nCells_infectedSamples))

adata_temp= adata[adata.obs['infection'] == 'Tg']
print('Cells with Tg counts >0%: {:d}'.format(sum(adata_temp.obs.pct_counts_tg > 0)))
print('Cells with Tg counts >0.07%: {:d}'.format(sum(adata_temp.obs.pct_counts_tg > 0.07)))
print('Cells with Tg counts >0.5%: {:d}'.format(sum(adata_temp.obs.pct_counts_tg > 0.5)))
print('Cells with Tg counts >1%: {:d}'.format(sum(adata_temp.obs.pct_counts_tg > 1)))
# Out:
# Total cells from infected explants: 27931
# Cells with Tg counts >0%: 5283
# Cells with Tg counts >0.07%: 1657
# Cells with Tg counts >0.5%: 960
# Cells with Tg counts >1%: 837
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
del(adata_temp)

# %% [markdown]
# ### Adding a flag to the metadata indicating if a cell is infected or not
#
# The criteria is to have a % of Tg counts >0.07

# %%
#Selecting the cells with %Tg>0
temp=adata.obs.pct_counts_tg > 0.07

#Adding aa new column with the flag in it. Boolean.
adata.obs['Tg_infected']= temp.astype("string")

# %% [markdown]
# ## Save raw counts

# %%
# adding the raw counts
adata.X=adata.layers['raw_counts'].copy()
#adata.raw = adata.copy
adata.write('../data/rna1_counts_Tg_adata.h5ad')
# Out:
# ... storing 'Tg_infected' as categorical
