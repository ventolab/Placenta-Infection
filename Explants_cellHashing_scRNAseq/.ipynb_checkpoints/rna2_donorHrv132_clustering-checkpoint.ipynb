# %% [markdown]
# **Author:** Regina Hoo
#
# **Institution:** Wellcome Sanger institute
#
# **April, 2023**

# %% [markdown]
# ---

# %% [markdown]
# ##  Clustering analysis of the HTO datasets - Donor Hrv132

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
import sys
import anndata
import scvi

    
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.figdir = './figures/clusters/'
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

sys.executable


fig_path= './figures/clusters/'
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.1
# sinfo       0.3.1
# -----
# PIL                 8.1.2
# absl                NA
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                3.1.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# numpy               1.20.1
# opt_einsum          v3.3.0
# packaging           20.9
# pandas              1.2.3
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyro                1.6.0
# pyrsistent          NA
# pytoml              NA
# pytorch_lightning   1.2.5
# pytz                2021.1
# requests            2.25.1
# rich                NA
# ruamel              NA
# scanpy              1.7.1
# scipy               1.6.1
# scvi                0.9.1
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.24.1
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# tensorboard         2.4.1
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# torch               1.8.1+cu102
# torchmetrics        0.2.0
# tornado             6.1
# tqdm                4.58.0
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.3.1
# zmq                 22.0.3
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-158-generic-x86_64-with-glibc2.10
# 60 logical CPU cores, x86_64
# -----
# Session information updated at 2023-02-15 02:32

# %%
def doublet_assing(adata_obj, cell_id):
    
    '''
    Function that assigns the "doublet" label to the cells that were pooled
    
    input
        adata_obj: adata object
        cell_id: ID of a sinfle cell

    '''
    
    #is_doublet label of the current cell, it's a boolean value
    curr_isDoublet = adata_obj.obs.loc[cell_id, 'is_doublet']


    #If the is_doublet is True, then the function willl return the "doublet"
    # Otherwise it will return the "singlet". 
    if curr_isDoublet == True:
        return("doublet")
    
    else:
        return("singlet")

# %%
#from HashSolo 
adata = sc.read('rna1_counts_HTO_adata_new.h5ad')
adata.X.shape
# Out:
# (19607, 36601)

# %%
adata.X=adata.layers['raw_counts'].copy()

# %% [markdown]
# # Analyse Donor Hrv132

# %%
adata = adata[adata.obs['donor'] != 'Hrv133']
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %% [markdown]
# ### Normalization

# %%
#Normalize and scale data to run neirest neighbors and plot gene expression
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
#sc.pp.scale(adata, max_value=10)
# Out:
# /opt/conda/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:138: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pp.neighbors(adata, n_neighbors=20)
sc.tl.umap(adata)
# Out:
# WARNING: You’re trying to run this on 36601 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
#clustering
sc.tl.leiden(adata, key_added="leiden", resolution=0.3)

# %%
sc.pl.umap(adata, color=["leiden",'Classification', 'n_genes', 'donor' ],
           ncols=2, wspace=0.3)

# %%
adata = adata[adata.obs['Classification'] != 'Negative']
adata = adata[adata.obs['Classification'] != 'Doublet']
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
sc.pl.umap(adata, color=["leiden",'Classification', 'n_genes', 'donor' ],
           ncols=2, wspace=0.3)

# %%
#Re-run leiden clustering

# %%
sc.pp.neighbors(adata, n_neighbors=15)
sc.tl.umap(adata)

# %%
#clustering
sc.tl.leiden(adata, key_added="leiden", resolution=0.2)

# %%
sc.pl.umap(adata, color=["leiden",'Classification', 'n_genes', 'donor' ],
           ncols=2, wspace=0.3)

# %%
def Barplot(which_var, adata, var='leiden', height=3, color = False, suffix= ''):
    
    '''
    Function to plot barplots plotting the proportion of cells per catergory in var, coming from each category in which_var.
    
    Parameters:
        which_var: column name in .obs. Contains the categories to contrast.
        adata: anndata object.
        var: column name in .obs. It contains the categories of the cells.
        height: plot height
        color: colors to use
        suffix: string. Suffix to be added at the end of the name of the plot.
    
    Return:
        Saves bar plot as a pdf.
        
    '''
    
    plotdata = pd.crosstab(adata.obs[var], adata.obs[which_var], normalize='index') * 100
    if 'category' in plotdata.index.dtype.name:
        plotdata.index.reorder_categories(adata.obs[var].cat.categories[::-1])

    if not color:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False)
    else:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False, 
                                 color = color)
    ax1.set_title(which_var+' %')
    ax1.set_ylabel(var)
    horiz_offset = 1
    vert_offset = 1.
    ax1 = ax1.legend(bbox_to_anchor = (horiz_offset, vert_offset))
    ax1.figure.savefig(str(sc.settings.figdir)+'/hrv132_barplot_'+var+'_proportions_'+which_var+ suffix+'.pdf',
                       bbox_inches='tight',
                       dpi=300, format= 'pdf', optimize=True)

# %%
Barplot('leiden', adata, var='Classification')
# Out:
# <ipython-input-16-0a48843361d5>:33: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "optimize" which is no longer supported as of 3.3 and will become an error two minor releases later
#   ax1.figure.savefig(str(sc.settings.figdir)+'/hrv132_barplot_'+var+'_proportions_'+which_var+ suffix+'.pdf',

# %% [raw]
# noHBadata= adata[adata.obs['leiden'] != '0']

# %% [raw]
# Barplot('leiden', noHBadata, var='tag')

# %% [raw]
# #Dictionary with marker genes per cell type. You can substitute this for a list of genes only.
# marker_genes = {
#     'Troph':{'GATA2','GATA3','EGFR'},
#     #'SCT':{'MFSD2A','SDC1','CYP19A1'}
#     'VCT-fusing': {'ERVFRD-1','ERVW-1','ERVV-1'},
#     'VCT': {'CDH1','TP63','PAGE4','BCAM'},
#     'VCT-P': {'MKI67'},
#     'VCT-CCC': {'ITGB6','LPCAT1'},
#
#
#     'EVT': {'CSH1',"HLA-G"},
#     'EVT-1': {'ACAN','ADAMTS20'},
#     'EVT-2': {'SERPINE2','ERBB2'},
#     'iEVT': {'PAPPA','PLAC8'},
#
#     'F1':{'DKK1','COL6A2',},
#     'F2': { 'AGTR1','PDGFRB','DLK1','MCAM','MYH11'},
#     'Endo f':{'PECAM1','CD34',}, #'LYVE1'
#
#     'HB': {'FCGR1A', 'FOLR2', 'LYVE1','CD14'},
#     'M3':{ 'MMP9','MGST1','CD9',},#"CHI3L1"
#
# }

# %% [markdown]
# ### Marker genes: plots

# %%
sc.pl.umap(adata, color=['leiden','KRT7','KRT18', 'TFAP2A', 'GATA2','GATA3','EGFR', #Trophoblast
                         'MFSD2A','SDC1','CYP19A1', #SCT
                         'ERVFRD-1','ERVW-1','ERVV-1', #VCT-fusing
                         'MKI67',#VCT-p
                         'CDH1','TP63','PAGE4','BCAM', #VCT
                         'ITGB6','LPCAT1', #VCT-CCC
                         'CSH1','HLA-G', #EVT
                         'ACAN', #EVT-1
                         'SERPINE2','ERBB2', #EVT-2
                         'PAPPA','PLAC8', #iEVT
                         'DKK1','COL6A2', #F1
                         'AGTR1','PDGFRB','DLK1','MCAM','MYH11', #F2
                         'CD34','PECAM1', #Endo
                         'FCGR1A', 'FOLR2', 'LYVE1','CD14', #HB
                         'MMP9','MGST1','CD9', #M3
                         'HBA1','HBA2','HBB', #Ery
                         'HLA-DRA',
                         'Classification'], use_raw=False, color_map='OrRd')

# %%
sc.pl.umap(adata, color=['CD4', 'CD69', 'PTPRC','IL1B','leiden' ],color_map='OrRd',use_raw=False)

# %% [markdown]
# ## Save raw counts

# %%
# adding the raw counts
adata.X=adata.layers['raw_counts']
#adata.raw = adata.copy
adata.write('rna2_counts_HTO_donorHrv132_cluster_adata.h5ad')

# %%
adata.obs.head()
# Out:
#                                                                                sample  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT  Pla_HDBR12261976_Pla_HDBR12261978
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC  Pla_HDBR12261976_Pla_HDBR12261978
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT  Pla_HDBR12261976_Pla_HDBR12261978
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC  Pla_HDBR12261976_Pla_HDBR12261978
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA  Pla_HDBR12261976_Pla_HDBR12261978
#
#                                                      donor termination day  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT  Hrv132    surgical  d0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC  Hrv132    surgical  d0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT  Hrv132    surgical  d0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC  Hrv132    surgical  d0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA  Hrv132    surgical  d0
#
#                                                       pcw  percent_mito  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT  12pcw      0.064380
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC  12pcw      0.104515
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT  12pcw      0.079663
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC  12pcw      0.072032
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA  12pcw      0.069400
#
#                                                     n_counts  n_genes batch  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT   13498.0     3876     0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC   17586.0     3657     0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT   10444.0     2878     0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC    7344.0     2876     0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA   15951.0     3684     0
#
#                                                      HTO3  ...  percent_ribo  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT  150.0  ...      0.132538
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC  134.0  ...      0.143751
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT  157.0  ...      0.188146
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC  151.0  ...      0.121187
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA  528.0  ...      0.149583
#
#                                                     doublet_scores  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT        0.044640
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC        0.092593
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT        0.156662
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC        0.064543
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA        0.103982
#
#                                                     predicted_doublets  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT               False
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC               False
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT               False
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC               False
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA               False
#
#                                                     most_likely_hypothesis  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT                       1
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC                       1
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT                       1
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC                       1
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA                       1
#
#                                                     cluster_feature  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT                0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC                0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT                0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC                0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA                0
#
#                                                     negative_hypothesis_probability  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT                     9.606343e-03
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC                     1.965559e-09
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT                     4.713975e-13
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC                     1.199405e-03
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA                     8.550814e-04
#
#                                                     singlet_hypothesis_probability  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT                        0.946434
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC                        0.975479
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT                        0.942854
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC                        0.952824
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA                        0.954583
#
#                                                     doublet_hypothesis_probability  \
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT                        0.043960
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC                        0.024521
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT                        0.057146
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC                        0.045977
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA                        0.044562
#
#                                                     Classification  leiden
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGAAGCGCT            HTO4       1
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGACTGTTC            HTO4       0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCATTGT            HTO4       0
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCCTCAGC            HTO4       7
# Pla_HDBR12261976_Pla_HDBR12261978_AAACCCAAGCGGGTTA            HTO3       0
#
# [5 rows x 26 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 7434 × 36601
#     obs: 'sample', 'donor', 'termination', 'day', 'pcw', 'percent_mito', 'n_counts', 'n_genes', 'batch', 'HTO3', 'HTO4', 'HTO5', 'total_hto_counts', 'fraction_HTO3', 'fraction_HTO4', 'fraction_HTO5', 'percent_ribo', 'doublet_scores', 'predicted_doublets', 'most_likely_hypothesis', 'cluster_feature', 'negative_hypothesis_probability', 'singlet_hypothesis_probability', 'doublet_hypothesis_probability', 'Classification', 'leiden'
#     var: 'gene_ids', 'feature_types'
#     uns: 'Classification_colors', 'log1p', 'neighbors', 'umap', 'leiden', 'leiden_colors', 'donor_colors'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'raw_counts'
#     obsp: 'distances', 'connectivities'
