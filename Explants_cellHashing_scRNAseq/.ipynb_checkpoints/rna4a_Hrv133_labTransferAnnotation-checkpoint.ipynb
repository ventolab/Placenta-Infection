# %% [markdown]
# **Author:** Regina Hoo
#
# **Institution:** Wellcome Sanger institute
#
# **April, 2023**

# %% [markdown]
# ---

# %% [markdown]
# # Notebook to explore cell type predictions product of the logistic regression from the MFI reference - Donor Hrv133

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
import sys
import anndata
import scvi

# %%
def MovePlots(plotpattern, subplotdir):
    os.system('mkdir -p '+str(sc.settings.figdir)+'/'+subplotdir)
    os.system('mv '+str(sc.settings.figdir)+'/*'+plotpattern+'** '+str(sc.settings.figdir)+'/'+subplotdir)

sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.figdir = './figures/annotation/'
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

sys.executable
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.1
# sinfo       0.3.1
# -----
# PIL                 8.1.2
# absl                NA
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                3.1.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# numpy               1.20.1
# opt_einsum          v3.3.0
# packaging           20.9
# pandas              1.2.3
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyro                1.6.0
# pyrsistent          NA
# pytoml              NA
# pytorch_lightning   1.2.5
# pytz                2021.1
# requests            2.25.1
# rich                NA
# ruamel              NA
# scanpy              1.7.1
# scipy               1.6.1
# scvi                0.9.1
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.24.1
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# tensorboard         2.4.1
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# torch               1.8.1+cu102
# torchmetrics        0.2.0
# tornado             6.1
# tqdm                4.58.0
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.3.1
# zmq                 22.0.3
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-112-generic-x86_64-with-glibc2.10
# 26 logical CPU cores, x86_64
# -----
# Session information updated at 2023-02-15 14:45
# '/opt/conda/bin/python'

# %% [raw]
# sc.set_figure_params(figsize=(6.5,6.5))

# %%
#Read donor Hrv133 which already had predicitions labeled

# %%
adata= sc.read('rna3_counts_HTO_donorHrv133_logRegression_adata.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10145 × 36601
#     obs: 'sample', 'donor', 'termination', 'day', 'pcw', 'percent_mito', 'n_counts', 'n_genes', 'batch', 'HTO3', 'HTO4', 'HTO5', 'total_hto_counts', 'fraction_HTO3', 'fraction_HTO4', 'fraction_HTO5', 'percent_ribo', 'doublet_scores', 'predicted_doublets', 'most_likely_hypothesis', 'cluster_feature', 'negative_hypothesis_probability', 'singlet_hypothesis_probability', 'doublet_hypothesis_probability', 'Classification', 'leiden', 'celltype_predictions', 'probabilities'
#     var: 'gene_ids', 'feature_types', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'Classification_colors', 'donor_colors', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %%
# use scVI imputed values for plotting
sc.pl.umap(adata, color=[ 'probabilities','celltype_predictions'])

# %% [markdown]
# ## Cluster pre-labeling
#
# The marker genes already reported for different cell types were intensively analysed, together with the clusters' markers, and the label trasfering.

# %%
data_dir = '/warehouse/team292_wh01/placenta_infection/data/explant_hashing/'
meta = pd.read_csv(data_dir+'/metadata_hashing.csv',index_col=0)
meta['donor'] = meta['donor'].astype('str')
plotmeta = list(meta.columns)
plotmeta.append('sample')
print('Number of samples: ', meta.index.size)
# Out:
# Number of samples:  2

# %%
meta
# Out:
#                                     donor termination day    pcw
# sample
# Pla_HDBR12261976_Pla_HDBR12261978  Hrv132    surgical  d0  12pcw
# Pla_HDBR12261977_Pla_HDBR12261979  Hrv133    surgical  d0  12pcw

# %% [raw]
# scorenames = ['scrublet_score','scrublet_cluster_score','zscore','bh_pval','bonf_pval']
#
# scrdf = []
# for sample in meta.index:
#     #reading the scrublet scores done in S0
#     scrdf.append(pd.read_csv('star-scrublet-scores/'+sample+'.csv', header=0, index_col=0))
# #scrdf.append(pd.read_csv('scrublet-scores/'+sample+'.csv', header=0, index_col=0))
# #scrdf.append(pd.read_csv('scrublet-scores/'+sample+'soupX.csv', header=0, index_col=0))
# scrdf = pd.concat(scrdf)
# #scrdf.index = [i.replace('-1', '') for i in scrdf.index]
# for score in scorenames:
#     adata.obs[score] = scrdf[score]
# # In scrublet the significant p-value mark doublets
# adata.obs['is_doublet'] = adata.obs['bonf_pval'] < 0.01

# %% [raw]
# print('Total number of doublets: {:d}'.format(len(adata.obs.loc[adata.obs['is_doublet'] == True])))

# %% [raw]
# adata

# %% [markdown]
# ## Re-run leiden clustering

# %%
sc.pp.neighbors(adata, n_neighbors=15)
sc.tl.umap(adata)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:30)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:04)

# %%
#clustering
sc.tl.leiden(adata, key_added="leiden", resolution=0.6)
# Out:
# running Leiden clustering
#     finished: found 20 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(adata, color=['leiden','Classification','probabilities','celltype_predictions','doublet_scores','n_genes', 'n_counts'],
           ncols=2, wspace=0.3)

# %% [markdown]
# ## Broad annotation of cell clusters

# %%
#Copying the value of the leiden cluster. The new column will help to change it's values for
# the cluster identity
adata.obs['identity']= adata.obs['leiden']

# %%
adata.obs['identity']
# Out:
# Pla_HDBR12261977_Pla_HDBR12261979_AAACCCAAGAGTGAAG     3
# Pla_HDBR12261977_Pla_HDBR12261979_AAACCCAAGGCACTAG     2
# Pla_HDBR12261977_Pla_HDBR12261979_AAACCCAAGTGAGTTA    10
# Pla_HDBR12261977_Pla_HDBR12261979_AAACCCACATCGCCTT     1
# Pla_HDBR12261977_Pla_HDBR12261979_AAACCCATCACCCTGT    10
#                                                       ..
# Pla_HDBR12261977_Pla_HDBR12261979_TTTGTTGGTGGCAGAT     0
# Pla_HDBR12261977_Pla_HDBR12261979_TTTGTTGGTTCAAGTC     0
# Pla_HDBR12261977_Pla_HDBR12261979_TTTGTTGTCGATGCAT     3
# Pla_HDBR12261977_Pla_HDBR12261979_TTTGTTGTCTAGGCCG     4
# Pla_HDBR12261977_Pla_HDBR12261979_TTTGTTGTCTCATTGT     2
# Name: identity, Length: 10145, dtype: category
# Categories (20, object): ['0', '1', '2', '3', ..., '16', '17', '18', '19']

# %%
#ranking genes check top genes
sc.tl.rank_genes_groups(adata, groupby='leiden', method='logreg')
# Out:
# ranking genes
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#  (0:02:50)

# %%
sc.pl.rank_genes_groups(adata)

# %%
#Big identity

# %%
adata.obs['identity'] = (adata.obs["leiden"].map(lambda x: 
                            {"0": "HB", "1": "Fibroblast", "2": "HB", "3": "Fibroblast","4": "Trophoblast", "5": "Endo_f", 
                             "6": "Trophoblast", "7": "Trophoblast",  "8": "Hb_p", "9": "PAMM1",  "10": "scrublet_doublet", "11": "HB", 
                              "12": "scrublet_doublet", "13": "Trophoblast", "14": "Fibroblast", "15": "lowQC",  "16": "Erythrocyte", 
                             "17": "scrublet_doublet", "18": "lowQC", "19": "scrublet_doublet"
                            }
                            .get(x, x)).astype("category"))

# %%
sc.pl.umap(adata, color=['identity', ], legend_loc='on data',legend_fontsize='xx-small')

# %% [markdown]
# ## Removal of scrublet doublets, doublet cluster, and Erythrocytes etc.

# %%
adata = adata[adata.obs['identity'] != 'Erythrocyte']
adata = adata[adata.obs['identity'] != 'scrublet_doublet']
adata = adata[adata.obs['identity'] != 'lowQC']
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
sc.pl.umap(adata, color=['identity', ], legend_loc='on data',legend_fontsize='xx-small')

# %% [markdown]
# ## Re-run leiden clustering

# %%
sc.pp.neighbors(adata, n_neighbors=20)
sc.tl.umap(adata)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:09)

# %%
#clustering
sc.tl.leiden(adata, key_added="leiden", resolution=0.8)
# Out:
# running Leiden clustering
#     finished: found 16 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:01)

# %%
sc.pl.umap(adata, color=['leiden','identity','Classification','probabilities','doublet_scores','n_genes', 'n_counts'],
           ncols=2, wspace=0.3)

# %%
sc.pl.umap(adata, color=['celltype_predictions'], ncols=2, wspace=0.3)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4490 × 16901
#     obs: 'sample', 'donor', 'termination', 'day', 'pcw', 'percent_mito', 'n_counts', 'batch', 'n_genes', 'sample_barcode', 'tag', 'HTO_counts', 'scrublet_score', 'scrublet_cluster_score', 'zscore', 'bh_pval', 'bonf_pval', 'is_doublet', 'S_score', 'G2M_score', 'phase', 'leiden', 'celltype_predictions', 'probabilities', 'identity'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'mean', 'std', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'donor_colors', 'hvg', 'leiden', 'neighbors', 'sample_colors', 'tag_colors', 'umap', 'celltype_predictions_colors', 'rank_genes_groups', 'identity_colors', 'leiden_colors'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %%
#Normalizing the data and scaling for the cell-cycle scoring
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)

# Scale
#sc.pp.scale(adata, max_value=10)
# Out:
# normalizing by total count per cell
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
sc.pl.umap(adata, color=['leiden','KRT7','KRT18', 'TFAP2A', 'GATA2','GATA3','EGFR', #Trophoblast
                         'MFSD2A','SDC1','CYP19A1', #SCT
                         'ERVFRD-1','ERVW-1','ERVV-1', #VCT-fusing
                         'MKI67',#VCT-p
                         'CDH1','TP63','PAGE4','BCAM', #VCT
                         'ITGB6','LPCAT1', #VCT-CCC
                         'CSH1','HLA-G', #EVT
                         'ACAN', #EVT-1
                         'SERPINE2','ERBB2', #EVT-2
                         'PAPPA','PLAC8', #iEVT
                         'DKK1','COL6A2', #F1
                         'AGTR1','PDGFRB','DLK1','MCAM','MYH11', #F2
                         'CD34','PECAM1', #Endo
                         'FCGR1A', 'FOLR2', 'LYVE1','CD14', #HB
                         'MMP9','MGST1','CD9', #M3
                         'HBA1','HBA2','HBB', #Ery
                         'IGFBP1', #dS
                         'IL1B', 'CXCL8', #inflammatory
                         'HLA-DRA',
                         ], use_raw=False, color_map='OrRd')

# %%
# adding the raw counts
adata.X=adata.layers['raw_counts']

# %%
adata.write('rna4_annotate_donorHrv133_all_noDoublets.h5ad')
